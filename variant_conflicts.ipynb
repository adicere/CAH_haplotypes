#               'father': 77095378},
#              77095377: {'sibling': 77095375,
#               'mother': 77095376,
#               'father': 77095378},
#              77095378: {'spouse': 77095376, 'child': 77095377},
#              77095374: {'child': 77095373},
#              77095373: {'mother': 77095374},
#              77092531: {'father': 77092530, 'mother': 77092529},
#              77092530: {'spouse': 77092529, 'child': 77092531},
#              77092529: {'spouse': 77092530, 'child': 77092531},
#              77095333: {'mother': 77092432,
#               'sibling': 77092433,
#               'father': 77092429},
#              77095330: {'spouse': 77095331, 'child': 77095332},
#              77095331: {'child': 77095332, 'spouse': 77095330},
#              77095332: {'mother': 77095330, 'father': 77095331},
#              77095328: {'spouse': 77095329, 'child': 77095348},
#              77095329: {'spouse': 77095328, 'child': 77095348},
#              77095348: {'father': 77095328,
#               'mother': 77095329,
#               'sibling': 77095327},
#              77095327: {'father': 77095328,
#               'mother': 77095329,
#               'sibling': 77095348},
#              77095326: {'father': 77095328,
#               'mother': 77095329,
#               'sibling': 77095348},
#              77092897: {'child': 77092898},
#              77092898: {'mother': 77092897},
#              77095322: {'child': 77095320, 'spouse': 77095321},
#              77095321: {'child': 77095320, 'spouse': 77095322},
#              77095320: {'mother': 77095321, 'father': 77095322},
#              77095325: {'child': 77095323},
#              77095324: {'father': 77095325, 'sibling': 77095323},
#              77095323: {'father': 77095325, 'sibling': 77095324},
#              77095319: {'spouse': 77095318, 'child': 77095316},
#              77095318: {'spouse': 77095319, 'child': 77095316},
#              77095317: {'father': 77095319,
#               'mother': 77095318,
#               'sibling': 77095316},
#              77095316: {'father': 77095319,
#               'mother': 77095318,
#               'sibling': 77095317},
#              77095313: {'spouse': 77095312, 'child': 77095311},
#              77095312: {'spouse': 77095313, 'child': 77095311},
#              77095311: {'mother': 77095313,
#               'father': 77095312,
#               'sibling': 77095315},
#              77095315: {'mother': 77095313,
#               'father': 77095312,
#               'sibling': 77095311},
#              77095314: {'mother': 77095313,
#               'father': 77095312,
#               'sibling': 77095311}})

# %%
files_list= pd.read_excel('/storage/haplotypes/resolve_conf.xlsx', index_col=0)
calling_region = [32037643, 32041345]

# %%
def read_vcf(link, mode=None): 
    vcf = pd.read_csv(link, sep='\t', comment='#', header=None,
          names=['CHROM', 'POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'FORMAT', 'SAMPLE'], index_col=False) 
    vcf = vcf.assign(GT=vcf['SAMPLE'].map(lambda x: x.split(':')[0]))
    if mode == 'hc':
        vcf = vcf.assign(AD=vcf['SAMPLE'].map(lambda x: x.split(':')[1]))
        vcf['DP'] = vcf['AD'].map(lambda x: sum(map(int, x.split(','))) if pd.notna(x) else None)
        vcf['DP'] = vcf['DP'].astype(int)
        vcf['GT'] = vcf['GT'].str.replace('/', '|', regex=False)
    if mode == 'dv':
        vcf = vcf.assign(AD=vcf['SAMPLE'].map(lambda x: x.split(':')[3]))
        vcf['DP'] = vcf['AD'].map(lambda x: sum(map(int, x.split(','))) if pd.notna(x) else None)
        vcf['GT'] = vcf['GT'].str.replace('|', '/', regex=False)
        vcf['DP'] = vcf['DP'].astype(int)
    if mode == 'bam':
        vcf = vcf.assign(AD=vcf['SAMPLE'].map(lambda x: x.split(':')[5]))
        vcf['DP'] = vcf['AD'].map(lambda x: sum(map(int, x.split(','))) if pd.notna(x) else None)
        vcf['DP'] = vcf['DP'].astype(int)
    
    return vcf

# %%
def gt_vectors(vcf, mode = None):
    gt_vector={}
    for idx, row in vcf.iterrows(): 
        if ',' in row['ALT']: 
            dp=int(row['AD'].split(',')[0])+int(row['AD'].split(',')[1]) + int(row['AD'].split(',')[2])
            if row['POS'] == 32038855:
                position = '32038855' + '_' + 'T' + "_" + 'TTTG'
                if mode == 'hc':
                    gt = '1|1'
                else:
                    gt='1/1'
                vaf=(int(row['AD'].split(',')[1]) + int(row['AD'].split(',')[2]))/dp
                gt_vector[position] = [gt, vaf, dp]
            else:
                for num, alt in enumerate(row['ALT'].split(',')):
                    position = str(row['POS']) + '_' + row['REF'] + "_" + alt
                    if mode == 'hc':
                        gt = '1|0'
                    else:
                        gt='1/0'
                    vaf=int(row['AD'].split(',')[num+1])/dp
                    gt_vector[position] = [gt, vaf, row['DP']]
                    
        else: 
            position=str(row['POS']) + '_' + row['REF'] + "_" + row['ALT']
            gt=row['GT']
            vaf=int(row['AD'].split(',')[1])/row['DP']
            gt_vector[position] = [gt, vaf, row['DP']]
    return gt_vector

# %%
#do I need DP checking here???
def check_relative_variant(position, hc_gen_info, dv_gen_info):
    print(f'checking relative variant with {hc_gen_info} AND {dv_gen_info}')
    hc_genotype=hc_gen_info[0]
    hc=hc_genotype.split('|')
    hc=int(hc[0])+int(hc[1])

    dv_genotype=dv_gen_info[0]
    dv=dv_genotype.split('/')
    dv=int(dv[0])+int(dv[1])

    if hc==dv:
        return hc_genotype
    else:
        if hc == 2:
            if hc_gen_info[1]>=0.85:
                if hc_gen_info[2] >= 30:
                    print(f'hc right with {hc_genotype}, VAF - {hc_gen_info[1]}, DP - {hc_gen_info[2]}')
                    return hc_genotype
                else:
                    print(f'hc call for {hc_genotype} with right VAF - {hc_gen_info[1]}, but low DP - {hc_gen_info[2]}')
                    return None
            if dv ==1 and (dv_gen_info[1] >= 0.2 and dv_gen_info[1] < 0.85):
                if dv_gen_info[2] >= 30:
                    print(f'dv right with {dv_genotype}, VAF - {dv_gen_info[1]}, DP - {dv_gen_info[2]}')
                    return dv_genotype
                else:
                    print(f'dv call for {dv_genotype} with right VAF - {dv_gen_info[1]}, but low DP - {dv_gen_info[2]}')
                    return None
            else:
                print(f'both callers have low qual variant in relative; HC: {hc_gen_info}, DV: {dv_gen_info}')
                return None
        if hc == 1:
            if (hc_gen_info[1] >= 0.2 and hc_gen_info[1] < 0.85):
                if hc_gen_info[2] >= 30:
                    print(f'hc_right with {hc_genotype}, VAF - {hc_gen_info[1]}, DP - {hc_gen_info[2]}')
                    return hc_genotype
                else:
                    print(f'hc call for {hc_genotype} with right VAF - {hc_gen_info[1]}, but low DP - {hc_gen_info[2]}')
                    return None
            if dv == 2 and dv_gen_info[1] >= 0.85:
                if dv_gen_info[2] >= 30:
                    print(f'dv right with {dv_genotype}, VAF - {dv_gen_info[1]}, DP - {dv_gen_info[2]}')
                    return dv_genotype
                else:
                    print(f'dv call for {dv_genotype} with right VAF - {dv_gen_info[1]}, but low DP - {dv_gen_info[2]}')
                    return None
            else:
                print(f'both callers have low qual variant in relative; HC: {hc_gen_info}, DV: {dv_gen_info}')
                return None

# %%
def check_inheritance(patient, pos, trios, gt_hc, gt_dv, gt_bam=None):
    found_in_both_parents=0
    if trios[patient] != {}:
        print(trios[patient])
    else:
        print(f'{patient} does not have relatives')
    inheritance=[]
    for rel in trios[patient].keys():
        if rel == 'child' or rel == 'mother' or rel == 'father':
            rel_num=int(trios[patient][rel])
            try:
                print(f'found {pos} in {rel_num} HC data - {gt_hc[rel_num][pos]}')
            except KeyError:
                print(f'{pos} not found in gt_hc of {rel_num} - the {rel} of {patient}')
                try:
                    print(f'found {pos} in {rel_num} DV data - {gt_dv[rel_num][pos]}')
                except KeyError:
                    print(f'{pos} not found in gt_dv of {rel_num} - the {rel} of {patient}')

            if pos in gt_hc[rel_num]:
                print(f'{pos} found in HC data of {rel}')
                hc_genotype=gt_hc[rel_num][pos][0]
                hc=hc_genotype.split('|')
                hc=int(hc[0])+int(hc[1])
                if hc == 2 and gt_hc[rel_num][pos][1]>=0.85:
                    if gt_hc[rel_num][pos][2]>=30:
                        print(f'found a homozygote {pos} in {rel} with VAF {gt_hc[rel_num][pos][1]}')
                        inheritance.append(hc_genotype)
                        if rel == 'mother' or rel == 'father':
                            found_in_both_parents+=1
                    else:
                        print(f'found a lowqual homozygote {pos} in {rel} with right VAF {gt_hc[rel_num][pos][1]}, but low DP - {gt_hc[rel_num][pos][2]}')
                        inheritance.append(hc_genotype)
                        if rel == 'mother' or rel == 'father':
                            found_in_both_parents+=1
                if hc == 1 and (gt_hc[rel_num][pos][1]>=0.2 and gt_hc[rel_num][pos][1]<0.85):
                    if gt_hc[rel_num][pos][2]>=30:
                        print(f'found a heterozygote {pos} in {rel} with VAF {gt_hc[rel_num][pos][1]}')
                        inheritance.append(hc_genotype)
                        if rel == 'mother' or rel == 'father':
                            found_in_both_parents+=1
                    else:
                        print(f'found a lowqual heterozygote {pos} in {rel} with right VAF {gt_hc[rel_num][pos][1]}, but low DP - {gt_hc[rel_num][pos][2]}')
                        inheritance.append(hc_genotype)
                        if rel == 'mother' or rel == 'father':
                            found_in_both_parents+=1
                else:
                    print(f'found only low qual {pos} in {rel} with {gt_hc[rel_num][pos][1]} and {gt_hc[rel_num][pos][2]}, probably an artefact')
            if pos in gt_dv[rel_num] and pos not in gt_hc[rel_num]:
                print(f'{pos} found only in DV data of {rel}')
                dv_genotype=gt_dv[rel_num][pos][0]
                dv=dv_genotype.split('/')
                dv=int(dv[0])+int(dv[1])
                if pos in gt_bam[rel_num].keys():
                    pp_value=gt_bam[rel_num][pos][0]
                    pp=pp_value.split('/')
                    pp=int(pp[0])+int(pp[1])
                    if pp==2 and gt_bam[rel_num][pos][1]>=0.85:
                        print(f'found a homozygote DV variant in {rel_num}')
                        inheritance.append(pp_value)
                        if rel == 'mother' or rel == 'father':
                            found_in_both_parents+=1
                    if pp==1 and (gt_bam[rel_num][pos][1]>=0.2 and gt_bam[rel_num][pos][1]<0.85):
                        print(f'found a heterozygote DV variant in {rel_num}')
                        inheritance.append(pp_value)
                        if rel == 'mother' or rel == 'father':
                            found_in_both_parents+=1
                # if dv == 2 and gt_dv[rel_num][pos][1]>=0.85:
                #     if gt_dv[rel_num][pos][2]>=30:
                #         print(f'found a homozygote {pos} in {rel} with VAF {gt_dv[rel_num][pos][1]}')
                #         inheritance.append(dv_genotype)
                #     else:
                #         print(f'found a lowqual homozygote {pos} in {rel} with right VAF {gt_dv[rel_num][pos][1]}, but low DP - {gt_dv[rel_num][pos][2]}')
                #         inheritance.append(dv_genotype)
                # if dv == 1 and (gt_dv[rel_num][pos][1]>=0.2 and gt_dv[rel_num][pos][1]<0.85):
                #     if gt_dv[rel_num][pos][2]>=30:
                #         print(f'found a heterozygote {pos} in {rel} with VAF {gt_dv[rel_num][pos][1]}')
                #         inheritance.append(dv_genotype)
                #     else:
                #         print(f'found a lowqual heterozygote {pos} in {rel} with right VAF {gt_dv[rel_num][pos][1]}, but low DP - {gt_dv[rel_num][pos][2]}')
                #         inheritance.append(dv_genotype)
                else:
                    print(f'cannot support found DV variant by bam, probably an artefact')

            if pos not in gt_hc[rel_num] and pos not in gt_dv[rel_num]:
                print(f'no {pos} found in {rel}')
    
    print(inheritance)
    if len(inheritance)>0:
        return True
    else:
        return False

# %%
def check_inheritance(patient, pos, trios, gt_hc, gt_dv):
    print(trios[patient])
    inheritance=[]
    for rel in trios[patient].keys():
        if rel == 'child' or rel == 'mother' or rel == 'father':
            rel_num=int(trios[patient][rel])
            try:
                print(f'found {pos} in {rel_num} HC data - {gt_hc[rel_num][pos]}')
            except KeyError:
                print(f'{pos} not found in gt_hc of {rel_num} - the {rel} of {patient}')
                try:
                    print(f'found {pos} in {rel_num} DV data - {gt_dv[rel_num][pos]}')
                except KeyError:
                    print(f'{pos} not found in gt_dv of {rel_num} - the {rel} of {patient}')
            if pos in gt_hc[rel_num] and pos in gt_dv[rel_num]:
                rel_gt_hc=gt_hc[rel_num][pos]
                rel_gt_dv = gt_dv[rel_num][pos]
                variant=check_relative_variant(pos, rel_gt_hc, rel_gt_dv)
                if variant!=None:
                    print(f'found {pos} in {rel} with genotype {variant}')
                    inheritance.append(variant)
            else:
                if pos in gt_hc[rel_num]:
                    print(f'{pos} found only in HC data of {rel}')
                    hc_genotype=gt_hc[rel_num][pos][0]
                    hc=hc_genotype.split('|')
                    hc=int(hc[0])+int(hc[1])
                    if hc == 2 and gt_hc[rel_num][pos][1]>=0.85:
                        if gt_hc[rel_num][pos][2]>=30:
                            print(f'found a homozygote {pos} in {rel} with VAF {gt_hc[rel_num][pos][1]}')
                            inheritance.append(hc_genotype)
                        else:
                            print(f'found a lowqual homozygote {pos} in {rel} with right VAF {gt_hc[rel_num][pos][1]}, but low DP - {gt_hc[rel_num][pos][2]}')
                            inheritance.append(hc_genotype)
                    if hc == 1 and (gt_hc[rel_num][pos][1]>=0.2 and gt_hc[rel_num][pos][1]<0.85):
                        if gt_hc[rel_num][pos][2]>=30:
                            print(f'found a heterozygote {pos} in {rel} with VAF {gt_hc[rel_num][pos][1]}')
                            inheritance.append(hc_genotype)
                        else:
                            print(f'found a lowqual heterozygote {pos} in {rel} with right VAF {gt_hc[rel_num][pos][1]}, but low DP - {gt_hc[rel_num][pos][2]}')
                            inheritance.append(hc_genotype)
                    else:
                        print(f'found only low qual {pos} in {rel} with {gt_hc[rel_num][pos][1]} and {gt_hc[rel_num][pos][2]}, probably an artefact')
                if pos in gt_dv[rel_num]:
                    print(f'{pos} found only in DV data of {rel}')
                    dv_genotype=gt_dv[rel_num][pos][0]
                    dv=dv_genotype.split('/')
                    dv=int(dv[0])+int(dv[1])
                    if dv == 2 and gt_dv[rel_num][pos][1]>=0.85:
                        if gt_dv[rel_num][pos][2]>=30:
                            print(f'found a homozygote {pos} in {rel} with VAF {gt_dv[rel_num][pos][1]}')
                            inheritance.append(dv_genotype)
                        else:
                            print(f'found a lowqual homozygote {pos} in {rel} with right VAF {gt_dv[rel_num][pos][1]}, but low DP - {gt_dv[rel_num][pos][2]}')
                            inheritance.append(dv_genotype)
                    if dv == 1 and (gt_dv[rel_num][pos][1]>=0.2 and gt_dv[rel_num][pos][1]<0.85):
                        if gt_dv[rel_num][pos][2]>=30:
                            print(f'found a heterozygote {pos} in {rel} with VAF {gt_dv[rel_num][pos][1]}')
                            inheritance.append(dv_genotype)
                        else:
                            print(f'found a lowqual heterozygote {pos} in {rel} with right VAF {gt_dv[rel_num][pos][1]}, but low DP - {gt_dv[rel_num][pos][2]}')
                            inheritance.append(dv_genotype)
                    else:
                        print(f'found only low qual {pos} in {rel} with {gt_dv[rel_num][pos][1]} and {gt_dv[rel_num][pos][2]}, probably an artefact')

                if pos not in gt_hc[rel_num] and pos not in gt_dv[rel_num]:
                    print(f'no {pos} found in {rel}')
    
    print(inheritance)
    if len(inheritance)>0:
        return True
    else:
        return False

# %%
#add DP checking
def check_variant(sample, pos, hc_genotype, dv_genotype, sample_hc_variants, sample_dv_variants, trios, gt_hc, gt_dv):
    hc=hc_genotype.split('|')
    hc=int(hc[0])+int(hc[1])
    dv=dv_genotype.split('/')
    dv=int(dv[0])+int(dv[1])
    if hc==dv:
        # print(f'{pos} are the same')
        return hc_genotype
    else:
        print(f'for {idx} comparing {pos} with HC - {hc_genotype} and DV - {dv_genotype}')
        if hc == 2:
            if sample_hc_variants[pos][1]>=0.85 and sample_hc_variants[pos][2]>=30:
                print(f'hc right with {hc_genotype}, VAF - {sample_hc_variants[pos][1]}, DP-{sample_hc_variants[pos][2]}')
                return hc_genotype
            if dv ==1 and (sample_dv_variants[pos][1] >= 0.2 and sample_dv_variants[pos][1] < 0.85) and sample_dv_variants[pos][2]>=30:
                print(f'dv right with {dv_genotype}, VAF - {sample_dv_variants[pos][1]}, DP-{sample_dv_variants[pos][2]}')
                return dv_genotype
            else:
                print(f'both wrong, checking inheritance; variant info: {hc_genotype}, {sample_hc_variants[pos][1]}, {sample_hc_variants[pos][2]} AND {dv_genotype}, {sample_dv_variants[pos][1]}, {sample_dv_variants[pos][2]}')
                inheritance = check_inheritance(sample, pos, hc_genotype, dv_genotype, sample_hc_variants, sample_dv_variants, trios, gt_hc, gt_dv)
                if inheritance == True:
                    print('saving this variant even with bad QUAL')
                    return hc_genotype
                else:
                    print('droping this variant, probably artefact')
        if hc == 1:
            if (sample_hc_variants[pos][1] >= 0.2 and sample_hc_variants[pos][1] < 0.85) and sample_hc_variants[pos][2]>=30:
                print(f'hc right with {hc_genotype}, VAF - {sample_hc_variants[pos][1]}, DP-{sample_hc_variants[pos][2]}')
                return hc_genotype
            if dv == 2 and sample_dv_variants[pos][1] >= 0.85 and sample_dv_variants[pos][2]>=30:
                print(f'dv right with {dv_genotype}, VAF - {sample_dv_variants[pos][1]}, DP-{sample_dv_variants[pos][2]}')
                return dv_genotype
            else:
                print(f'both wrong, checking inheritance; variant info: {hc_genotype}, {sample_hc_variants[pos][1]}, {sample_hc_variants[pos][2]} AND {dv_genotype}, {sample_dv_variants[pos][1]}, {sample_dv_variants[pos][2]}')
                inheritance = check_inheritance(sample, pos, trios, gt_hc, gt_dv)
                if inheritance == True:
                    print('saving this variant even with bad QUAL')
                    return hc_genotype
                else:
                    print('droping this variant, probably artefact')

# %%
gt_hc=defaultdict(dict)
gt_dv=defaultdict(dict)
gt_bam=defaultdict(dict)
for idx, row in files_list.iterrows():
    # dv
    vcf = read_vcf(row['dv'], mode = 'dv')
    vcf = vcf[vcf['FILTER'] == 'PASS']
    vcf = vcf[(vcf['POS'] >= calling_region[0]) & (vcf['POS'] <= calling_region[1])]
    gt_dv[idx]=gt_vectors(vcf, mode = 'dv')
    # hc 
    vcf = read_vcf(row['hc'], mode='hc')
    vcf = vcf[(vcf['POS'] >= calling_region[0]) & (vcf['POS'] <= calling_region[1])]
    gt_hc[idx]=gt_vectors(vcf, mode= 'hc')
    #bam
    vcf = read_vcf(row['pileup'], mode='bam')
    vcf = vcf[(vcf['POS'] >= calling_region[0]) & (vcf['POS'] <= calling_region[1])]
    gt_bam[idx]=gt_vectors(vcf, mode= 'dv')

# %%
res = defaultdict(dict)
for idx, row in files_list.iterrows():
    # dv
    vcf = read_vcf(row['dv'], mode = 'dv')
    vcf = vcf[vcf['FILTER'] == 'PASS']
    vcf = vcf[(vcf['POS'] >= calling_region[0]) & (vcf['POS'] <= calling_region[1])]
    sample_dv=gt_vectors(vcf, mode = 'dv')
    # hc 
    vcf = read_vcf(row['hc'], mode='hc')
    vcf = vcf[(vcf['POS'] >= calling_region[0]) & (vcf['POS'] <= calling_region[1])]
    sample_hc=gt_vectors(vcf, mode= 'hc')

    #pileup
    vcf = read_vcf(row['pileup'], mode='bam')
    vcf = vcf[(vcf['POS'] >= calling_region[0]) & (vcf['POS'] <= calling_region[1])]
    sample_pp=gt_vectors(vcf, mode= 'dv')

    print(f'checking variants for {idx}')
    for position in sample_hc.keys():
        hc_value=sample_hc[position][0]
        hc=hc_value.split('|')
        hc=int(hc[0])+int(hc[1])
        if position in sample_dv.keys():
            dv_value=sample_dv[position][0]
            dv=dv_value.split('/')
            dv=int(dv[0])+int(dv[1])
            if hc == dv:
                # print(f'no conflict for {position} in {idx}, saving HC genotype')
                res[idx][position] = hc_value
            if hc!=dv:
                if hc == 2:
                    if sample_hc[position][1] > 0.85 and sample_hc[position][2]>=30:
                        res[idx][position] = hc_value
                    else:
                        print(f'check {position}: HC - {sample_hc[position]}, DV - {dv_value}, bam - {sample_pp.get(position, 'Not found in bam')}')
                        if position in sample_pp.keys():
                            pp_value=sample_pp[position][0]
                            pp=pp_value.split('/')
                            pp=int(pp[0])+int(pp[1])
                            if pp==2 and sample_pp[position][1]>=0.85:
                                res[idx][position]  = hc_value
                                print(f'HC genotype is supported by bam')
                            if pp==1 and (sample_pp[position][1]>=0.2 and sample_pp[position][1]<0.85):
                                print(f'HC genotype is not supported by bam, saving a new genotype')
                                print(sample_pp[position])
                                res[idx][position] = pp_value
                        else:
                            print('need to check inheritance')
                            inheritance = check_inheritance(idx, position, trios, gt_hc, gt_dv, gt_bam)
                            if inheritance == True:
                                print('saving this variant even with bad QUAL')
                                res[idx][position]  = hc_value
                            else:
                                print('droping this variant, probably artefact')
                                
                if hc == 1: 
                    if (sample_hc[position][1] >= 0.2 and sample_hc[position][1] < 0.85) and sample_hc[position][2]>=30:
                        res[idx][position]  = hc_value
                    else:
                        print(f'check {position}: HC - {sample_hc[position]}, DV - {dv_value}, {sample_pp.get(position, 'Not found in bam')}')
                        if position in sample_pp.keys():
                            pp_value=sample_pp[position][0]
                            pp=pp_value.split('/')
                            pp=int(pp[0])+int(pp[1])
                            if pp==1 and (sample_pp[position][1]>=0.2 and sample_pp[position][1]<0.85):
                                res[idx][position]  = hc_value
                                print(f'HC genotype is supported by bam')
                            if pp==2 and sample_pp[position][1]>=0.85:
                                print(f'HC genotype is not supported by bam, saving a new genotype')
                                print(sample_pp[position])
                                res[idx][position] = pp_value
                        else:
                            print('need to check inheritance')
                            inheritance = check_inheritance(idx, position, trios, gt_hc, gt_dv, gt_bam)
                            if inheritance == True:
                                print('saving this variant even with bad QUAL')
                                res[idx][position]  = hc_value
                            else:
                                print('droping this variant, probably artefact')
        else:
            hc_value=sample_hc[position][0]
            hc=hc_value.split('|')
            hc=int(hc[0])+int(hc[1])
            if hc == 2:
                if sample_hc[position][1] >= 0.85 and sample_hc[position][2]>=30:
                    res[idx][position]  = hc_value
                else:
                    print(idx)
                    print(f'check {position}: HC - {sample_hc[position]}, DV - not called, bam - {sample_pp.get(position, 'Not found in bam')}')
                    if position in sample_pp.keys():
                        pp_value=sample_pp[position][0]
                        pp=pp_value.split('/')
                        pp=int(pp[0])+int(pp[1])
                        if pp==2 and sample_pp[position][1]>=0.85:
                            res[idx][position]  = hc_value
                            print(f'genotype is supported by bam')
                        if pp==1 and (sample_pp[position][1]>=0.2 and sample_pp[position][1]<0.85):
                            print(f'HC genotype is not supported by bam, saving a new genotype')
                            res[idx][position]  = pp_value
                    else:
                        print('need to check inheritance')
                        inheritance = check_inheritance(idx, position, trios, gt_hc, gt_dv, gt_bam)
                        if inheritance == True:
                            print('saving this variant even with bad QUAL')
                            res[idx][position]  = hc_value
                        else:
                            print('droping this variant, probably artefact')
            if hc == 1:
                if (sample_hc[position][1] >= 0.2 and sample_hc[position][1] < 0.85):
                    res[idx][position]  = hc_value
                else:             
                    print(idx)
                    print(f'check {position}: HC - {sample_hc[position]}, DV - not called, {sample_pp.get(position, 'Not found in bam')}')
                    if position in sample_pp.keys():
                        pp_value=sample_pp[position][0]
                        pp=pp_value.split('/')
                        pp=int(pp[0])+int(pp[1])
                        if hc == pp and (sample_pp[position][1] >= 0.2 and sample_pp[position][1]<0.85):
                            res[idx][position]  = hc_value
                            print(f'HC genotype is supported by bam')
                        else:
                            print(f'HC genotype is not supported by bam, saving a new genotype')
                            print(sample_pp[position])
                            res[idx][position]  = pp_value
                    else:
                        print('need to check inheritance')
                        inheritance = check_inheritance(idx, position, trios, gt_hc, gt_dv, gt_bam)
                        if inheritance == True:
                            print('saving this variant even with bad QUAL')
                            res[idx][position]  = hc_value
                        else:
                            print('droping this variant, probably artefact')
    for position in sample_dv.keys():
        if position not in res[idx].keys():
            print(f'{position} in {idx} found in DV, but not in HC, checking it')
            dv_value=sample_dv[position][0]
            dv=dv_value.split('/')
            dv=int(dv[0])+int(dv[1])
            if dv == 2:
                if position in sample_pp.keys():
                    if sample_pp[position][1]> 0.85:
                        print(f'{position} not called by HC, saving it with {dv_value}, {sample_pp[position]}')
                        res[idx][position] = dv_value
                else:
                    print(f'low qual {position} in {idx}, checking inheritance; variant info: {dv_value}')
                    inheritance = check_inheritance(idx, position, trios, gt_hc, gt_dv, gt_bam)
                    if inheritance == True:
                        print('saving this variant even with bad QUAL')
                        res[idx][position] = dv_value
                    else:
                        print('droping this variant, probably artefact')
            if dv == 1:
                if position in sample_pp.keys():
                    if (sample_pp[position][1] >= 0.2 and sample_pp[position][1] < 0.85):
                        print(f'{position} not called by HC, saving it with {dv_value}, {sample_pp[position]}')
                        res[idx][position] = dv_value
                else:
                    print(f'low qual {position} in {idx}, checking inheritance; variant info: {dv_value}')
                    inheritance = check_inheritance(idx, position, trios, gt_hc, gt_dv, gt_bam)
                    if inheritance == True:
                        print('saving this variant even with bad QUAL')
                        res[idx][position] = dv_value
                    else:
                        print('droping this variant, probably artefact')
# Out:
# checking variants for 77050386
# checking variants for 77091048
# checking variants for 77092306
# checking variants for 77092307
# checking variants for 77092308
# checking variants for 77092309
# checking variants for 77092310
# checking variants for 77092311
# checking variants for 77092312
# 32039081_C_G in 77092312 found in DV, but not in HC, checking it
# 32039081_C_G not called by HC, saving it with 1/1, ['1/1', 0.997539975399754, 1626]
# checking variants for 77092313
# checking variants for 77092314
# checking variants for 77092315
# checking variants for 77092316
# checking variants for 77092317
# checking variants for 77092319
# checking variants for 77092320
# checking variants for 77092321
# checking variants for 77092322
# checking variants for 77092323
# checking variants for 77092324
# checking variants for 77092327
# checking variants for 77092329
# checking variants for 77092344
# checking variants for 77092345
# checking variants for 77092346
# checking variants for 77092347
# checking variants for 77092348
# checking variants for 77092351
# checking variants for 77092352
# checking variants for 77092353
# checking variants for 77092354
# checking variants for 77092355
# checking variants for 77092356
# checking variants for 77092357
# checking variants for 77092358
# checking variants for 77092359
# checking variants for 77092360
# checking variants for 77092361
# checking variants for 77092362
# checking variants for 77092363
# checking variants for 77092364
# checking variants for 77092365
# checking variants for 77092366
# checking variants for 77092367
# checking variants for 77092368
# checking variants for 77092370
# check 32038949_T_G: HC - ['1|1', 1.0, 25], DV - 1/0, bam - ['1/0', 0.35555555555555557, 90]
# HC genotype is not supported by bam, saving a new genotype
# ['1/0', 0.35555555555555557, 90]
# check 32038962_A_ATCC: HC - ['0|1', 0.8823529411764706, 17], DV - 1/1, Not found in bam
# need to check inheritance
# {'father': 77092368, 'mother': 77092371}
# found 32038962_A_ATCC in 77092368 HC data - ['1|0', 0.6018518518518519, 108]
# 32038962_A_ATCC found in HC data of father
# found a heterozygote 32038962_A_ATCC in father with VAF 0.6018518518518519
# found 32038962_A_ATCC in 77092371 HC data - ['1|0', 0.5107340720221607, 2888]
# 32038962_A_ATCC found in HC data of mother
# found a heterozygote 32038962_A_ATCC in mother with VAF 0.5107340720221607
# ['1|0', '1|0']
# saving this variant even with bad QUAL
# 77092370
# check 32039001_G_C: HC - ['1|1', 1.0, 13], DV - not called, bam - ['1/1', 0.9290322580645162, 155]
# genotype is supported by bam
# 32038949_T_C in 77092370 found in DV, but not in HC, checking it
# 32038949_T_C not called by HC, saving it with 1/0, ['1/0', 0.5666666666666667, 90]
# checking variants for 77092371
# checking variants for 77092374
# checking variants for 77092375
# checking variants for 77092376
# 32038895_A_G in 77092376 found in DV, but not in HC, checking it
# 32038895_A_G not called by HC, saving it with 0/1, ['0/1', 0.45, 680]
# checking variants for 77092377
# 77092377
# check 32039006_G_A: HC - ['0|1', 0.16883116883116883, 77], DV - not called, Not found in bam
# need to check inheritance
# {'mother': 77092375, 'sibling': 77092376}
# 32039006_G_A not found in gt_hc of 77092375 - the mother of 77092377
# 32039006_G_A not found in gt_dv of 77092375 - the mother of 77092377
# no 32039006_G_A found in mother
# []
# droping this variant, probably artefact
# checking variants for 77092378
# checking variants for 77092379
# checking variants for 77092380
# checking variants for 77092381
# checking variants for 77092382
# checking variants for 77092383
# checking variants for 77092384
# 77092384
# check 32039046_A_G: HC - ['1|0', 0.8666666666666667, 15], DV - not called, ['0/1', 0.5272727272727272, 165]
# HC genotype is supported by bam
# checking variants for 77092385
# checking variants for 77092386
# checking variants for 77092387
# checking variants for 77092388
# 32038949_T_C in 77092388 found in DV, but not in HC, checking it
# 32038949_T_C not called by HC, saving it with 1/0, ['1/0', 0.5176470588235295, 85]
# checking variants for 77092389
# checking variants for 77092390
# checking variants for 77092391
# checking variants for 77092392
# checking variants for 77092393
# 77092393
# check 32039006_G_A: HC - ['1|0', 0.08333333333333333, 72], DV - not called, Not found in bam
# need to check inheritance
# {'mother': 77092394, 'father': 77092395}
# 32039006_G_A not found in gt_hc of 77092394 - the mother of 77092393
# 32039006_G_A not found in gt_dv of 77092394 - the mother of 77092393
# no 32039006_G_A found in mother
# 32039006_G_A not found in gt_hc of 77092395 - the father of 77092393
# 32039006_G_A not found in gt_dv of 77092395 - the father of 77092393
# no 32039006_G_A found in father
# []
# droping this variant, probably artefact
# checking variants for 77092394
# checking variants for 77092395
# checking variants for 77092396
# checking variants for 77092397
# checking variants for 77092398
# 77092398
# check 32038515_G_A: HC - ['1|0', 0.10059171597633136, 169], DV - not called, Not found in bam
# need to check inheritance
# {'mother': 77092396, 'sibling': 77092397, 'father': 77092399}
# 32038515_G_A not found in gt_hc of 77092396 - the mother of 77092398
# 32038515_G_A not found in gt_dv of 77092396 - the mother of 77092398
# no 32038515_G_A found in mother
# 32038515_G_A not found in gt_hc of 77092399 - the father of 77092398
# 32038515_G_A not found in gt_dv of 77092399 - the father of 77092398
# no 32038515_G_A found in father
# []
# droping this variant, probably artefact
# checking variants for 77092399
# checking variants for 77092400
# checking variants for 77092401
# 32038820_C_T in 77092401 found in DV, but not in HC, checking it
# 32038820_C_T not called by HC, saving it with 0/1, ['0/1', 0.5477178423236515, 482]
# 32038844_A_C in 77092401 found in DV, but not in HC, checking it
# 32038844_A_C not called by HC, saving it with 1/1, ['1/1', 0.9639423076923077, 416]
# 32038855_T_TTTG in 77092401 found in DV, but not in HC, checking it
# low qual 32038855_T_TTTG in 77092401, checking inheritance; variant info: 1/1
# {'father': 77092400, 'mother': 77092402, 'sibling': 77092403}
# found 32038855_T_TTTG in 77092400 HC data - ['0|1', 0.42424242424242425, 165]
# 32038855_T_TTTG found in HC data of father
# found a heterozygote 32038855_T_TTTG in father with VAF 0.42424242424242425
# found 32038855_T_TTTG in 77092402 HC data - ['0|1', 0.41420118343195267, 169]
# 32038855_T_TTTG found in HC data of mother
# found a heterozygote 32038855_T_TTTG in mother with VAF 0.41420118343195267
# ['0|1', '0|1']
# saving this variant even with bad QUAL
# 32038857_A_T in 77092401 found in DV, but not in HC, checking it
# 32038857_A_T not called by HC, saving it with 1/1, ['1/1', 0.9815668202764977, 217]
# 32038867_T_G in 77092401 found in DV, but not in HC, checking it
# 32038867_T_G not called by HC, saving it with 1/1, ['1/1', 0.9822784810126582, 395]
# 32038878_C_T in 77092401 found in DV, but not in HC, checking it
# 32038878_C_T not called by HC, saving it with 1/1, ['1/1', 0.9975, 400]
# 32038895_A_G in 77092401 found in DV, but not in HC, checking it
# 32038895_A_G not called by HC, saving it with 1/1, ['1/1', 1.0, 378]
# 32038949_T_C in 77092401 found in DV, but not in HC, checking it
# 32038949_T_C not called by HC, saving it with 1/0, ['1/0', 0.4482758620689655, 87]
# checking variants for 77092402
# checking variants for 77092403
# checking variants for 77092404
# checking variants for 77092405
# checking variants for 77092406
# checking variants for 77092407
# checking variants for 77092408
# checking variants for 77092409
# checking variants for 77092410
# checking variants for 77092411
# checking variants for 77092412
# checking variants for 77092413
# checking variants for 77092414
# checking variants for 77092415
# checking variants for 77092416
# checking variants for 77092417
# 32039081_C_G in 77092417 found in DV, but not in HC, checking it
# 32039081_C_G not called by HC, saving it with 1/1, ['1/1', 0.9924859110832811, 1597]
# checking variants for 77092418
# 32039081_C_G in 77092418 found in DV, but not in HC, checking it
# 32039081_C_G not called by HC, saving it with 1/1, ['1/1', 0.9878190255220418, 1724]
# checking variants for 77092419
# checking variants for 77092420
# checking variants for 77092421
# checking variants for 77092422
# checking variants for 77092423
# checking variants for 77092424
# checking variants for 77092425
# checking variants for 77092426
# checking variants for 77092428
# checking variants for 77092430
# checking variants for 77092431
# checking variants for 77092434
# checking variants for 77092435
# checking variants for 77092436
# 32039081_C_G in 77092436 found in DV, but not in HC, checking it
# 32039081_C_G not called by HC, saving it with 1/1, ['1/1', 0
DV - not called, Not found in bam
# need to check inheritance
# {'spouse': 77092530, 'child': 77092531}
# 32038962_A_ATCC not found in gt_hc of 77092531 - the child of 77092529
# found 32038962_A_ATCC in 77092531 DV data - ['1/1', 0.9333333333333333, 60]
# 32038962_A_ATCC found only in DV data of child
# cannot support found DV variant by bam, probably an artefact
# []
# droping this variant, probably artefact
# 77092529
# check 32038971_C_A: HC - ['0|1', 0.19230769230769232, 26], DV - not called, ['0/1', 0.35544041450777203, 965]
# HC genotype is supported by bam
# 77092529
# check 32038983_TG_T: HC - ['0|1', 0.125, 24], DV - not called, Not found in bam
# need to check inheritance
# {'spouse': 77092530, 'child': 77092531}
# 32038983_TG_T not found in gt_hc of 77092531 - the child of 77092529
# 32038983_TG_T not found in gt_dv of 77092531 - the child of 77092529
# no 32038983_TG_T found in child
# []
# droping this variant, probably artefact
# 77092529
# check 32038997_TGG_T: HC - ['0|1', 0.11538461538461539, 26], DV - not called, Not found in bam
# need to check inheritance
# {'spouse': 77092530, 'child': 77092531}
# 32038997_TGG_T not found in gt_hc of 77092531 - the child of 77092529
# 32038997_TGG_T not found in gt_dv of 77092531 - the child of 77092529
# no 32038997_TGG_T found in child
# []
# droping this variant, probably artefact
# 77092529
# check 32039001_G_C: HC - ['0|1', 0.125, 24], DV - not called, Not found in bam
# need to check inheritance
# {'spouse': 77092530, 'child': 77092531}
# 32039001_G_C not found in gt_hc of 77092531 - the child of 77092529
# 32039001_G_C not found in gt_dv of 77092531 - the child of 77092529
# no 32039001_G_C found in child
# []
# droping this variant, probably artefact
# 77092529
# check 32039002_G_A: HC - ['0|1', 0.125, 24], DV - not called, Not found in bam
# need to check inheritance
# {'spouse': 77092530, 'child': 77092531}
# 32039002_G_A not found in gt_hc of 77092531 - the child of 77092529
# found 32039002_G_A in 77092531 DV data - ['1/1', 0.9487179487179487, 39]
# 32039002_G_A found only in DV data of child
# cannot support found DV variant by bam, probably an artefact
# []
# droping this variant, probably artefact
# checking variants for 77092530
# 77092530
# check 32038983_TG_T: HC - ['0|1', 0.1875, 32], DV - not called, Not found in bam
# need to check inheritance
# {'spouse': 77092529, 'child': 77092531}
# 32038983_TG_T not found in gt_hc of 77092531 - the child of 77092530
# 32038983_TG_T not found in gt_dv of 77092531 - the child of 77092530
# no 32038983_TG_T found in child
# []
# droping this variant, probably artefact
# checking variants for 77092531
# check 32038139_A_G: HC - ['1|0', 0.8936170212765957, 47], DV - 1/1, ['1/1', 0.9912225705329154, 1595]
# HC genotype is not supported by bam, saving a new genotype
# ['1/1', 0.9912225705329154, 1595]
# check 32038141_T_G: HC - ['1|0', 0.8958333333333334, 48], DV - 1/1, ['1/1', 0.9878493317132442, 1646]
# HC genotype is not supported by bam, saving a new genotype
# ['1/1', 0.9878493317132442, 1646]
# check 32038844_A_C: HC - ['1|0', 0.38461538461538464, 13], DV - 1/1, ['1/1', 0.8616044090630741, 1633]
# HC genotype is not supported by bam, saving a new genotype
# ['1/1', 0.8616044090630741, 1633]
# 77092531
# check 32038847_A_ATTT: HC - ['1|1', 0.8, 10], DV - not called, bam - Not found in bam
# need to check inheritance
# {'father': 77092530, 'mother': 77092529}
# 32038847_A_ATTT not found in gt_hc of 77092530 - the father of 77092531
# 32038847_A_ATTT not found in gt_dv of 77092530 - the father of 77092531
# no 32038847_A_ATTT found in father
# 32038847_A_ATTT not found in gt_hc of 77092529 - the mother of 77092531
# 32038847_A_ATTT not found in gt_dv of 77092529 - the mother of 77092531
# no 32038847_A_ATTT found in mother
# []
# droping this variant, probably artefact
# 77092531
# check 32039081_C_A: HC - ['1|1', 1.0, 9], DV - not called, bam - Not found in bam
# need to check inheritance
# {'father': 77092530, 'mother': 77092529}
# found 32039081_C_A in 77092530 HC data - ['1|0', 0.5331325301204819, 332]
# 32039081_C_A found in HC data of father
# found a heterozygote 32039081_C_A in father with VAF 0.5331325301204819
# found 32039081_C_A in 77092529 HC data - ['1|0', 0.8709677419354839, 93]
# 32039081_C_A found in HC data of mother
# found only low qual 32039081_C_A in mother with 0.8709677419354839 and 93, probably an artefact
# ['1|0']
# saving this variant even with bad QUAL
# 32038855_T_TTTG in 77092531 found in DV, but not in HC, checking it
# low qual 32038855_T_TTTG in 77092531, checking inheritance; variant info: 1/1
# {'father': 77092530, 'mother': 77092529}
# found 32038855_T_TTTG in 77092530 HC data - ['0|1', 0.40540540540540543, 111]
# 32038855_T_TTTG found in HC data of father
# found a heterozygote 32038855_T_TTTG in father with VAF 0.40540540540540543
# found 32038855_T_TTTG in 77092529 HC data - ['0|1', 0.3805309734513274, 113]
# 32038855_T_TTTG found in HC data of mother
# found a heterozygote 32038855_T_TTTG in mother with VAF 0.3805309734513274
# ['0|1', '0|1']
# saving this variant even with bad QUAL
# 32038867_T_G in 77092531 found in DV, but not in HC, checking it
# 32038867_T_G not called by HC, saving it with 1/1, ['1/1', 0.9936421435059037, 1101]
# 32038895_A_G in 77092531 found in DV, but not in HC, checking it
# 32038895_A_G not called by HC, saving it with 1/1, ['1/1', 0.9889807162534435, 1089]
# 32038903_A_G in 77092531 found in DV, but not in HC, checking it
# 32038903_A_G not called by HC, saving it with 1/1, ['1/1', 0.9932301740812379, 1034]
# 32038911_A_G in 77092531 found in DV, but not in HC, checking it
# 32038911_A_G not called by HC, saving it with 1/1, ['1/1', 0.9841740850642928, 1011]
# 32038927_A_G in 77092531 found in DV, but not in HC, checking it
# 32038927_A_G not called by HC, saving it with 1/1, ['1/1', 0.9926082365364308, 947]
# 32038938_T_G in 77092531 found in DV, but not in HC, checking it
# 32038938_T_G not called by HC, saving it with 1/1, ['1/1', 0.9907940161104718, 869]
# 32038948_T_TC in 77092531 found in DV, but not in HC, checking it
# low qual 32038948_T_TC in 77092531, checking inheritance; variant info: 1/1
# {'father': 77092530, 'mother': 77092529}
# found 32038948_T_TC in 77092530 HC data - ['0|1', 0.4576271186440678, 59]
# 32038948_T_TC found in HC data of father
# found a heterozygote 32038948_T_TC in father with VAF 0.4576271186440678
# found 32038948_T_TC in 77092529 HC data - ['0|1', 0.18518518518518517, 27]
# 32038948_T_TC found in HC data of mother
# found only low qual 32038948_T_TC in mother with 0.18518518518518517 and 27, probably an artefact
# ['0|1']
# saving this variant even with bad QUAL
# 32038949_T_G in 77092531 found in DV, but not in HC, checking it
# low qual 32038949_T_G in 77092531, checking inheritance; variant info: 1/1
# {'father': 77092530, 'mother': 77092529}
# found 32038949_T_G in 77092530 HC data - ['0|1', 0.5254237288135594, 59]
# 32038949_T_G found in HC data of father
# found a heterozygote 32038949_T_G in father with VAF 0.5254237288135594
# found 32038949_T_G in 77092529 HC data - ['0|1', 0.17857142857142858, 28]
# 32038949_T_G found in HC data of mother
# found only low qual 32038949_T_G in mother with 0.17857142857142858 and 28, probably an artefact
# ['0|1']
# saving this variant even with bad QUAL
# 32038955_A_T in 77092531 found in DV, but not in HC, checking it
# 32038955_A_T not called by HC, saving it with 1/1, ['1/1', 0.988394584139265, 517]
# 32038962_A_ATCC in 77092531 found in DV, but not in HC, checking it
# low qual 32038962_A_ATCC in 77092531, checking inheritance; variant info: 1/1
# {'father': 77092530, 'mother': 77092529}
# found 32038962_A_ATCC in 77092530 HC data - ['0|1', 0.36585365853658536, 41]
# 32038962_A_ATCC found in HC data of father
# found a heterozygote 32038962_A_ATCC in father with VAF 0.36585365853658536
# found 32038962_A_ATCC in 77092529 HC data - ['0|1', 0.19230769230769232, 26]
# 32038962_A_ATCC found in HC data of mother
# found only low qual 32038962_A_ATCC in mother with 0.19230769230769232 and 26, probably an artefact
# ['0|1']
# saving this variant even with bad QUAL
# 32038971_C_A in 77092531 found in DV, but not in HC, checking it
# 32038971_C_A not called by HC, saving it with 1/1, ['1/1', 0.8599033816425121, 828]
# 32039002_G_A in 77092531 found in DV, but not in HC, checking it
# low qual 32039002_G_A in 77092531, checking inheritance; variant info: 1/1
# {'father': 77092530, 'mother': 77092529}
# found 32039002_G_A in 77092530 HC data - ['0|1', 0.23255813953488372, 43]
# 32039002_G_A found in HC data of father
# found a heterozygote 32039002_G_A in father with VAF 0.23255813953488372
# found 32039002_G_A in 77092529 HC data - ['0|1', 0.125, 24]
# 32039002_G_A found in HC data of mother
# found only low qual 32039002_G_A in mother with 0.125 and 24, probably an artefact
# ['0|1']
# saving this variant even with bad QUAL
# 32039015_G_T in 77092531 found in DV, but not in HC, checking it
# 32039015_G_T not called by HC, saving it with 1/1, ['1/1', 0.904487917146145, 869]
# 32039027_C_A in 77092531 found in DV, but not in HC, checking it
# 32039027_C_A not called by HC, saving it with 1/1, ['1/1', 0.9360967184801382, 1158]
# 32039046_A_G in 77092531 found in DV, but not in HC, checking it
# 32039046_A_G not called by HC, saving it with 1/1, ['1/1', 0.9910931174089069, 1235]
# 32039050_G_T in 77092531 found in DV, but not in HC, checking it
# 32039050_G_T not called by HC, saving it with 1/1, ['1/1', 0.9918962722852512, 1234]
# 32039055_C_G in 77092531 found in DV, but not in HC, checking it
# 32039055_C_G not called by HC, saving it with 1/1, ['1/1', 0.9903225806451613, 1240]
# 32039081_C_G in 77092531 found in DV, but not in HC, checking it
# 32039081_C_G not called by HC, saving it with 1/1, ['1/1', 0.9939718687206965, 1493]
# checking variants for 77092532
# checking variants for 77092533
# checking variants for 77092534
# checking variants for 77092535
# checking variants for 77092536
# checking variants for 77092537
# checking variants for 77092538
# checking variants for 77092539
# checking variants for 77092540
# checking variants for 77092541
# checking variants for 77092542
# checking variants for 77092543
# checking variants for 77092544
# checking variants for 77092545
# checking variants for 77092546
# checking variants for 77092547
# checking variants for 77092548
# checking variants for 77092549
# checking variants for 77092550
# checking variants for 77092551
# checking variants for 77092552
# checking variants for 77092553
# checking variants for 77092554
# checking variants for 77092555
# checking variants for 77092556
# checking variants for 77092561
# checking variants for 77092562
# checking variants for 77092563
# checking variants for 77092564
# 77092564
# check 32038948_T_TC: HC - ['0|1', 0.14285714285714285, 140], DV - not called, Not found in bam
# need to check inheritance
# {'sibling': 77092563, 'mother': 77092565}
# 32038948_T_TC not found in gt_hc of 77092565 - the mother of 77092564
# 32038948_T_TC not found in gt_dv of 77092565 - the mother of 77092564
# no 32038948_T_TC found in mother
# []
# droping this variant, probably artefact
# 77092564
# check 32038949_T_G: HC - ['0|1', 0.14285714285714285, 140], DV - not called, Not found in bam
# need to check inheritance
# {'sibling': 77092563, 'mother': 77092565}
# 32038949_T_G not found in gt_hc of 77092565 - the mother of 77092564
# 32038949_T_G not found in gt_dv of 77092565 - the mother of 77092564
# no 32038949_T_G found in mother
# []
# droping this variant, probably artefact
# 77092564
# check 32038955_A_T: HC - ['0|1', 0.14814814814814814, 135], DV - not called, ['0/1', 0.2916666666666667, 768]
# HC genotype is supported by bam
# 77092564
# check 32038962_A_ATCC: HC - ['0|1', 0.08620689655172414, 58], DV - not called, Not found in bam
# need to check inheritance
# {'sibling': 77092563, 'mother': 77092565}
# 32038962_A_ATCC not found in gt_hc of 77092565 - the mother of 77092564
# 32038962_A_ATCC not found in gt_dv of 77092565 - the mother of 77092564
# no 32038962_A_ATCC found in mother
# []
# droping this variant, probably artefact
# 77092564
# check 32038983_TG_T: HC - ['0|1', 0.1111111111111111, 36], DV - not called, Not found in bam
# need to check inheritance
# {'sibling': 77092563, 'mother': 77092565}
# 32038983_TG_T not found in gt_hc of 77092565 - the mother of 77092564
# 32038983_TG_T not found in gt_dv of 77092565 - the mother of 77092564
# no 32038983_TG_T found in mother
# []
# droping this variant, probably artefact
# 77092564
# check 32038997_TGG_T: HC - ['0|1', 0.1282051282051282, 39], DV - not called, Not found in bam
# need to check inheritance
# {'sibling': 77092563, 'mother': 77092565}
# 32038997_TGG_T not found in gt_hc of 77092565 - the mother of 77092564
# 32038997_TGG_T not found in gt_dv of 77092565 - the mother of 77092564
# no 32038997_TGG_T found in mother
# []
# droping this variant, probably artefact
# 77092564
# check 32039001_G_C: HC - ['0|1', 0.15151515151515152, 33], DV - not called, Not found in bam
# need to check inheritance
# {'sibling': 77092563, 'mother': 77092565}
# 32039001_G_C not found in gt_hc of 77092565 - the mother of 77092564
# 32039001_G_C not found in gt_dv of 77092565 - the mother of 77092564
# no 32039001_G_C found in mother
# []
# droping this variant, probably artefact
# 77092564
# check 32039002_G_A: HC - ['0|1', 0.15151515151515152, 33], DV - not called, Not found in bam
# need to check inheritance
# {'sibling': 77092563, 'mother': 77092565}
# 32039002_G_A not found in gt_hc of 77092565 - the mother of 77092564
# 32039002_G_A not found in gt_dv of 77092565 - the mother of 77092564
# no 32039002_G_A found in mother
# []
# droping this variant, probably artefact
# 32038903_A_G in 77092564 found in DV, but not in HC, checking it
# check 32039046_A_G: HC - ['0|1', 0.8717948717948718, 39], DV - not called, ['0/1', 0.5794392523364486, 321]
# HC genotype is supported by bam
# checking variants for 77092636
# checking variants for 77092637
# checking variants for 77092638
# checking variants for 77092639
# checking variants for 77092640
# check 32038949_T_G: HC - ['1|1', 1.0, 24], DV - 1/0, bam - Not found in bam
# need to check inheritance
# {'mother': 77092629, 'father': 77092630}
# found 32038949_T_G in 77092629 HC data - ['0|1', 0.4861111111111111, 288]
# 32038949_T_G found in HC data of mother
# found a heterozygote 32038949_T_G in mother with VAF 0.4861111111111111
# 32038949_T_G not found in gt_hc of 77092630 - the father of 77092640
# 32038949_T_G not found in gt_dv of 77092630 - the father of 77092640
# no 32038949_T_G found in father
# ['0|1']
# saving this variant even with bad QUAL
# 77092640
# check 32039001_G_C: HC - ['1|1', 1.0, 27], DV - not called, bam - ['1/1', 0.95, 120]
# genotype is supported by bam
# 32038949_T_C in 77092640 found in DV, but not in HC, checking it
# checking variants for 77092641
# checking variants for 77092644
# checking variants for 77092645
# checking variants for 77092646
# checking variants for 77092647
# checking variants for 77092648
# checking variants for 77092649
# checking variants for 77092650
# checking variants for 77092651
# checking variants for 77092652
# checking variants for 77092653
# checking variants for 77092654
# checking variants for 77092655
# checking variants for 77092657
# checking variants for 77092658
# checking variants for 77092659
# checking variants for 77092660
# checking variants for 77092661
# checking variants for 77092662
# checking variants for 77092663
# checking variants for 77092664
# checking variants for 77092665
# checking variants for 77092666
# 77092666
# check 32038948_T_TC: HC - ['0|1', 0.14285714285714285, 14], DV - not called, Not found in bam
# need to check inheritance
# 77092666 does not have relatives
# []
# droping this variant, probably artefact
# 77092666
# check 32038949_T_G: HC - ['0|1', 0.14285714285714285, 14], DV - not called, Not found in bam
# need to check inheritance
# 77092666 does not have relatives
# []
# droping this variant, probably artefact
# 77092666
# check 32038955_A_T: HC - ['0|1', 0.125, 16], DV - not called, Not found in bam
# need to check inheritance
# 77092666 does not have relatives
# []
# droping this variant, probably artefact
# checking variants for 77092667
# checking variants for 77092668
# checking variants for 77092669
# checking variants for 77092670
# checking variants for 77092671
# 77092671
# check 32038962_A_ATCC: HC - ['0|1', 0.11678832116788321, 137], DV - not called, Not found in bam
# need to check inheritance
# 77092671 does not have relatives
# []
# droping this variant, probably artefact
# 77092671
# check 32038971_C_A: HC - ['0|1', 0.11594202898550725, 138], DV - not called, ['0/1', 0.3330739299610895, 1285]
# HC genotype is supported by bam
# 32038895_A_G in 77092671 found in DV, but not in HC, checking it
# 32038895_A_G not called by HC, saving it with 0/1, ['0/1', 0.39581881533101043, 1435]
# 32038903_A_G in 77092671 found in DV, but not in HC, checking it
# 32038903_A_G not called by HC, saving it with 0/1, ['0/1', 0.41710427606901723, 1333]
# 32038911_A_G in 77092671 found in DV, but not in HC, checking it
# 32038911_A_G not called by HC, saving it with 0/1, ['0/1', 0.3890160183066362, 1311]
# 32038927_A_G in 77092671 found in DV, but not in HC, checking it
# 32038927_A_G not called by HC, saving it with 0/1, ['0/1', 0.41051805337519626, 1274]
# 32038938_T_G in 77092671 found in DV, but not in HC, checking it
# 32038938_T_G not called by HC, saving it with 0/1, ['0/1', 0.4178628389154705, 1254]
# checking variants for 77092672
# checking variants for 77092673
# 32038878_C_T in 77092673 found in DV, but not in HC, checking it
# 32038878_C_T not called by HC, saving it with 1/1, ['1/1', 0.9970980847359258, 1723]
# checking variants for 77092674
# 77092674
# check 32038539_C_CTTG: HC - ['1|0', 0.1694915254237288, 59], DV - not called, Not found in bam
# need to check inheritance
# 77092674 does not have relatives
# []
# droping this variant, probably artefact
# 77092674
# check 32038997_TGG_T: HC - ['0|1', 0.15873015873015872, 63], DV - not called, Not found in bam
# need to check inheritance
# 77092674 does not have relatives
# []
# droping this variant, probably artefact
# 77092674
# check 32039001_G_C: HC - ['0|1', 0.15517241379310345, 58], DV - not called, Not found in bam
# need to check inheritance
# 77092674 does not have relatives
# []
# droping this variant, probably artefact
# 77092674
# check 32039002_G_A: HC - ['0|1', 0.15789473684210525, 57], DV - not called, Not found in bam
# need to check inheritance
# 77092674 does not have relatives
# []
# droping this variant, probably artefact
# 77092674
# check 32040112_G_GCA: HC - ['0|1', 0.12643678160919541, 174], DV - not called, Not found in bam
# need to check inheritance
# 77092674 does not have relatives
# []
# droping this variant, probably artefact
# 32038844_A_C in 77092674 found in DV, but not in HC, checking it
# 32038844_A_C not called by HC, saving it with 0/1, ['0/1', 0.39467592592592593, 1728]
# 32038855_T_TTTG in 77092674 found in DV, but not in HC, checking it
# low qual 32038855_T_TTTG in 77092674, checking inheritance; variant info: 0/1
# 77092674 does not have relatives
# []
# droping this variant, probably artefact
# 32038857_A_T in 77092674 found in DV, but not in HC, checking it
# low qual 32038857_A_T in 77092674, checking inheritance; variant info: 0/1
# 77092674 does not have relatives
# []
# droping this variant, probably artefact
# 32038867_T_G in 77092674 found in DV, but not in HC, checking it
# 32038867_T_G not called by HC, saving it with 0/1, ['0/1', 0.42654364797728883, 1409]
# 32038878_C_T in 77092674 found in DV, but not in HC, checking it
# 32038878_C_T not called by HC, saving it with 0/1, ['0/1', 0.4298245614035088, 1368]
# 32038895_A_G in 77092674 found in DV, but not in HC, checking it
# 32038895_A_G not called by HC, saving it with 0/1, ['0/1', 0.42243975903614456, 1328]
# checking variants for 77092675
# checking variants for 77092676
# checking variants for 77092677
# checking variants for 77092678
# checking variants for 77092679
# checking variants for 77092687
# checking variants for 77092688
# checking variants for 77092689
# checking variants for 77092690
# checking variants for 77092691
# checking variants for 77092692
# checking variants for 77092693
# checking variants for 77092694
# checking variants for 77092695
# checking variants for 77092696
# checking variants for 77092697
# checking variants for 77092702
# checking variants for 77092703
# checking variants for 77092704
# checking variants for 77092705
# 32039081_C_G in 77092705 found in DV, but not in HC, checking it
# 32039081_C_G not called by HC, saving it with 1/1, ['1/1', 0
# ['0|1']
# saving this variant even with bad QUAL
# check 32038857_A_T: HC - ['1|0', 0.7692307692307693, 13], DV - 1/1, ['1/1', 0.9485294117647058, 544]
# HC genotype is not supported by bam, saving a new genotype
# ['1/1', 0.9485294117647058, 544]
# 77092898
# check 32039001_G_C: HC - ['1|1', 1.0, 20], DV - not called, bam - ['1/1', 0.9280575539568345, 278]
# genotype is supported by bam
# 77092898
# check 32039007_A_AAG: HC - ['1|1', 1.0, 15], DV - not called, bam - Not found in bam
# need to check inheritance
# {'mother': 77092897}
# found 32039007_A_AAG in 77092897 HC data - ['0|1', 0.6, 15]
# 32039007_A_AAG found in HC data of mother
# found a lowqual heterozygote 32039007_A_AAG in mother with right VAF 0.6, but low DP - 15
# ['0|1']
# saving this variant even with bad QUAL
# 32038867_T_G in 77092898 found in DV, but not in HC, checking it
# 32038867_T_G not called by HC, saving it with 1/1, ['1/1', 0.9952076677316294, 1252]
# 32038878_C_T in 77092898 found in DV, but not in HC, checking it
# 32038878_C_T not called by HC, saving it with 1/1, ['1/1', 0.9951923076923077, 1248]
# 32038895_A_G in 77092898 found in DV, but not in HC, checking it
# 32038895_A_G not called by HC, saving it with 1/1, ['1/1', 0.9974619289340102, 1182]
# 32038903_A_G in 77092898 found in DV, but not in HC, checking it
# 32038903_A_G not called by HC, saving it with 1/1, ['1/1', 0.9982062780269059, 1115]
# checking variants for 77092899
# checking variants for 77092900
# 77092900
# check 32038962_A_ATCC: HC - ['1|0', 0.07246376811594203, 138], DV - not called, Not found in bam
# need to check inheritance
# 77092900 does not have relatives
# []
# droping this variant, probably artefact
# 77092900
# check 32038971_C_A: HC - ['1|0', 0.10416666666666667, 96], DV - not called, ['0/1', 0.380997177798683, 1063]
# HC genotype is supported by bam
# 77092900
# check 32039050_G_T: HC - ['1|0', 0.16666666666666666, 12], DV - not called, ['0/1', 0.40584415584415584, 1232]
# HC genotype is supported by bam
# 77092900
# check 32039056_A_G: HC - ['1|0', 0.16666666666666666, 12], DV - not called, ['0/1', 0.38384615384615384, 1300]
# HC genotype is supported by bam
# 32038938_T_G in 77092900 found in DV, but not in HC, checking it
# 32038938_T_G not called by HC, saving it with 0/1, ['0/1', 0.43699731903485256, 1119]
# checking variants for 77092901
# checking variants for 77092902
# checking variants for 77093060
# checking variants for 77093072
# checking variants for 77093073
# checking variants for 77093074
# checking variants for 77093075
# checking variants for 77093076
# checking variants for 77093077
# checking variants for 77093109
# checking variants for 77093110
# checking variants for 77093111
# checking variants for 77093137
# checking variants for 77093138
# checking variants for 77093139
# checking variants for 77093142
# checking variants for 77093143
# checking variants for 77093144
# checking variants for 77093145
# checking variants for 77093146
# checking variants for 77093147
# checking variants for 77093148
# checking variants for 77093149
# checking variants for 77093150
# checking variants for 77093153
# checking variants for 77093155
# checking variants for 77093156
# checking variants for 77093157
# checking variants for 77093158
# checking variants for 77093192
# checking variants for 77093202
# checking variants for 77093203
# checking variants for 77093204
# checking variants for 77093207
# checking variants for 77093216
# checking variants for 77093217
# checking variants for 77093249
# checking variants for 77093250
# checking variants for 77093251
# checking variants for 77093257
# checking variants for 77093258
# checking variants for 77093259
# checking variants for 77093451
# checking variants for 77093452
# checking variants for 77093453
# checking variants for 77093459
# checking variants for 77093476
# checking variants for 77093477
# checking variants for 77093480
# checking variants for 77093483
# checking variants for 77093491
# checking variants for 77093492
# checking variants for 77093493
# checking variants for 77093494
# checking variants for 77093496
# checking variants for 77093619
# checking variants for 77093620
# checking variants for 77093621
# checking variants for 77093640
# checking variants for 77093641
# checking variants for 77093643
# checking variants for 77093646
# checking variants for 77093647
# checking variants for 77093648
# checking variants for 77095100
# 77095100
# check 32038878_C_T: HC - ['0|1', 0.12365591397849462, 186], DV - not called, ['0/1', 0.4177708495713172, 1283]
# HC genotype is supported by bam
# 77095100
# check 32038971_C_A: HC - ['0|1', 0.19047619047619047, 42], DV - not called, ['0/1', 0.33186813186813185, 910]
# HC genotype is supported by bam
# 77095100
# check 32039001_G_C: HC - ['0|1', 0.19444444444444445, 36], DV - not called, Not found in bam
# need to check inheritance
# 77095100 does not have relatives
# []
# droping this variant, probably artefact
# checking variants for 77095101
# 77095101
# check 32039046_A_G: HC - ['0|1', 0.13636363636363635, 22], DV - not called, ['0/1', 0.4199424736337488, 1043]
# HC genotype is supported by bam
# 77095101
# check 32039055_C_G: HC - ['0|1', 0.11475409836065574, 61], DV - not called, ['0/1', 0.3966725043782837, 1142]
# HC genotype is supported by bam
# 77095101
# check 32039056_A_G: HC - ['0|1', 0.11475409836065574, 61], DV - not called, ['0/1', 0.398576512455516, 1124]
# HC genotype is supported by bam
# 32039081_C_G in 77095101 found in DV, but not in HC, checking it
# 32039081_C_G not called by HC, saving it with 1/0, ['1/0', 0.4518581081081081, 1184]
# checking variants for 77095102
# checking variants for 77095103
# 32038855_T_TTTG in 77095103 found in DV, but not in HC, checking it
# low qual 32038855_T_TTTG in 77095103, checking inheritance; variant info: 0/1
# 77095103 does not have relatives
# []
# droping this variant, probably artefact
# 32038857_A_T in 77095103 found in DV, but not in HC, checking it
# low qual 32038857_A_T in 77095103, checking inheritance; variant info: 0/1
# 77095103 does not have relatives
# []
# droping this variant, probably artefact
# checking variants for 77095104
# checking variants for 77095105
# checking variants for 77095106
# 77095106
# check 32038948_T_TC: HC - ['1|0', 0.14130434782608695, 184], DV - not called, Not found in bam
# need to check inheritance
# 77095106 does not have relatives
# []
# droping this variant, probably artefact
# 77095106
# check 32038949_T_G: HC - ['1|0', 0.14130434782608695, 184], DV - not called, Not found in bam
# need to check inheritance
# 77095106 does not have relatives
# []
# droping this variant, probably artefact
# 77095106
# check 32038955_A_T: HC - ['1|0', 0.1452513966480447, 179], DV - not called, ['0/1', 0.2923728813559322, 944]
# HC genotype is supported by bam
# 77095106
# check 32038962_A_ATCC: HC - ['1|0', 0.0958904109589041, 73], DV - not called, Not found in bam
# need to check inheritance
# 77095106 does not have relatives
# []
# droping this variant, probably artefact
# 77095106
# check 32038971_C_A: HC - ['1|0', 0.08823529411764706, 68], DV - not called, ['0/1', 0.32129277566539927, 1052]
# HC genotype is supported by bam
# 77095106
# ...
# found a lowqual heterozygote 32038983_TG_T in father with right VAF 0.6296296296296297, but low DP - 27
# ['0|1', '0|1']
# saving this variant even with bad QUAL
# 32038997_TGG_T in 77095336 found in DV, but not in HC, checking it
# low qual 32038997_TGG_T in 77095336, checking inheritance; variant info: 1/1
# {'sibling': 77095335, 'mother': 77095334, 'father': 77095340}
# found 32038997_TGG_T in 77095334 HC data - ['0|1', 0.4444444444444444, 27]
# 32038997_TGG_T found in HC data of mother
# found a lowqual heterozygote 32038997_TGG_T in mother with right VAF 0.4444444444444444, but low DP - 27
# found 32038997_TGG_T in 77095340 HC data - ['0|1', 0.47058823529411764, 17]
# 32038997_TGG_T found in HC data of father
# found a lowqual heterozygote 32038997_TGG_T in father with right VAF 0.47058823529411764, but low DP - 17
# ['0|1', '0|1']
# saving this variant even with bad QUAL
# 32039002_G_A in 77095336 found in DV, but not in HC, checking it
# low qual 32039002_G_A in 77095336, checking inheritance; variant info: 1/1
# {'sibling': 77095335, 'mother': 77095334, 'father': 77095340}
# found 32039002_G_A in 77095334 HC data - ['0|1', 0.5217391304347826, 23]
# 32039002_G_A found in HC data of mother
# found a lowqual heterozygote 32039002_G_A in mother with right VAF 0.5217391304347826, but low DP - 23
# found 32039002_G_A in 77095340 HC data - ['0|1', 0.5, 14]
# 32039002_G_A found in HC data of father
# found a lowqual heterozygote 32039002_G_A in father with right VAF 0.5, but low DP - 14
# ['0|1', '0|1']
# saving this variant even with bad QUAL
# 32039007_A_AAG in 77095336 found in DV, but not in HC, checking it
# low qual 32039007_A_AAG in 77095336, checking inheritance; variant info: 1/1
# {'sibling': 77095335, 'mother': 77095334, 'father': 77095340}
# found 32039007_A_AAG in 77095334 HC data - ['0|1', 0.6666666666666666, 24]
# 32039007_A_AAG found in HC data of mother
# found a lowqual heterozygote 32039007_A_AAG in mother with right VAF 0.6666666666666666, but low DP - 24
# found 32039007_A_AAG in 77095340 HC data - ['0|1', 0.5, 12]
# 32039007_A_AAG found in HC data of father
# found a lowqual heterozygote 32039007_A_AAG in father with right VAF 0.5, but low DP - 12
# ['0|1', '0|1']
# saving this variant even with bad QUAL
# 32039015_G_T in 77095336 found in DV, but not in HC, checking it
# 32039015_G_T not called by HC, saving it with 1/1, ['1/1', 0.889922480620155, 645]
# 32039020_G_A in 77095336 found in DV, but not in HC, checking it
# 32039020_G_A not called by HC, saving it with 1/1, ['1/1', 0.9424460431654677, 695]
# 32039027_C_A in 77095336 found in DV, but not in HC, checking it
# 32039027_C_A not called by HC, saving it with 1/1, ['1/1', 0.9324796274738067, 859]
# 32039046_A_G in 77095336 found in DV, but not in HC, checking it
# 32039046_A_G not called by HC, saving it with 1/1, ['1/1', 1.0, 926]
# 32039050_G_T in 77095336 found in DV, but not in HC, checking it
# 32039050_G_T not called by HC, saving it with 1/1, ['1/1', 0.9989212513484358, 927]
# 32039055_C_G in 77095336 found in DV, but not in HC, checking it
# 32039055_C_G not called by HC, saving it with 1/1, ['1/1', 1.0, 923]
# 32039056_A_G in 77095336 found in DV, but not in HC, checking it
# 32039056_A_G not called by HC, saving it with 1/1, ['1/1', 1.0, 923]
# 32039081_C_G in 77095336 found in DV, but not in HC, checking it
# 32039081_C_G not called by HC, saving it with 1/1, ['1/1', 0.9982300884955753, 1130]
# 32039109_G_A in 77095336 found in DV, but not in HC, checking it
# 32039109_G_A not called by HC, saving it with 1/1, ['1/1', 0.9527638190954774, 995]
# 32039128_C_G in 77095336 found in DV, but not in HC, checking it
# 32039128_C_G not called by HC, saving it with 1/1, ['1/1', 0.9793233082706767, 532]
# 32039132_GGAGACTAC_G in 77095336 found in DV, but not in HC, checking it
# low qual 32039132_GGAGACTAC_G in 77095336, checking inheritance; variant info: 1/1
# {'sibling': 77095335, 'mother': 77095334, 'father': 77095340}
# found 32039132_GGAGACTAC_G in 77095334 HC data - ['0|1', 0.4037854889589905, 317]
# 32039132_GGAGACTAC_G found in HC data of mother
# found a heterozygote 32039132_GGAGACTAC_G in mother with VAF 0.4037854889589905
# found 32039132_GGAGACTAC_G in 77095340 HC data - ['0|1', 0.3870967741935484, 248]
# 32039132_GGAGACTAC_G found in HC data of father
# found a heterozygote 32039132_GGAGACTAC_G in father with VAF 0.3870967741935484
# ['0|1', '0|1']
# saving this variant even with bad QUAL
# 32039143_C_T in 77095336 found in DV, but not in HC, checking it
# checking variants for 77095337
# checking variants for 77095338
# 77095338
# check 32038997_TGG_T: HC - ['1|0', 0.16279069767441862, 43], DV - not called, Not found in bam
# need to check inheritance
# {'sibling': 77095337, 'father': 77095339, 'mother': 77095341}
# found 32038997_TGG_T in 77095339 HC data - ['0|1', 0.4722222222222222, 36]
# 32038997_TGG_T found in HC data of father
# found a heterozygote 32038997_TGG_T in father with VAF 0.4722222222222222
# 32038997_TGG_T not found in gt_hc of 77095341 - the mother of 77095338
# 32038997_TGG_T not found in gt_dv of 77095341 - the mother of 77095338
# no 32038997_TGG_T found in mother
# ['0|1']
# saving this variant even with bad QUAL
# 77095338
# check 32039001_G_C: HC - ['1|0', 0.15625, 32], DV - not called, Not found in bam
# need to check inheritance
# {'sibling': 77095337, 'father': 77095339, 'mother': 77095341}
# found 32039001_G_C in 77095339 HC data - ['0|1', 0.37777777777777777, 45]
# 32039001_G_C found in HC data of father
# found a heterozygote 32039001_G_C in father with VAF 0.37777777777777777
# 32039001_G_C not found in gt_hc of 77095341 - the mother of 77095338
# 32039001_G_C not found in gt_dv of 77095341 - the mother of 77095338
# no 32039001_G_C found in mother
# ['0|1']
# saving this variant even with bad QUAL
# 77095338
# check 32039002_G_A: HC - ['1|0', 0.16129032258064516, 31], DV - not called, Not found in bam
# need to check inheritance
# {'sibling': 77095337, 'father': 77095339, 'mother': 77095341}
# found 32039002_G_A in 77095339 HC data - ['0|1', 0.3695652173913043, 46]
# 32039002_G_A found in HC data of father
# found a heterozygote 32039002_G_A in father with VAF 0.3695652173913043
# 32039002_G_A not found in gt_hc of 77095341 - the mother of 77095338
# 32039002_G_A not found in gt_dv of 77095341 - the mother of 77095338
# no 32039002_G_A found in mother
# ['0|1']
# saving this variant even with bad QUAL
# 77095338
# check 32039015_G_T: HC - ['1|0', 0.18518518518518517, 27], DV - not called, ['0/1', 0.3539518900343643, 1164]
# HC genotype is supported by bam
# 77095338
# check 32039020_G_A: HC - ['1|0', 0.18518518518518517, 27], DV - not called, ['0/1', 0.3851851851851852, 1215]
# HC genotype is supported by bam
# 77095338
# check 32039027_C_A: HC - ['1|0', 0.14705882352941177, 34], DV - not called, ['0/1', 0.4237947122861586, 1286]
# HC genotype is supported by bam
# 77095338
# check 32039056_A_G: HC - ['1|0', 0.17647058823529413, 136], DV - not called, ['0/1', 0.39257673090649536, 1401]
# HC genotype is supported by bam
# checking variants for 77095339
# checking variants for 77095340
# checking variants for 77095341
# checking variants for 77095342
# 77095342
# check 32038962_A_ATCC: HC - ['0|1', 0.17857142857142858, 28], DV - not called, Not found in bam
# need to check inheritance
# {'spouse': 77095343, 'child': 77095344}
# found 32038962_A_ATCC in 77095344 HC data - ['1|0', 0.35, 40]
# 32038962_A_ATCC found in HC data of child
# found a heterozygote 32038962_A_ATCC in child with VAF 0.35
# ['1|0']
# saving this variant even with bad QUAL
# 77095342
# check 32038983_TG_T: HC - ['0|1', 0.10714285714285714, 28], DV - not called, Not found in bam
# need to check inheritance
# {'spouse': 77095343, 'child': 77095344}
# 32038983_TG_T not found in gt_hc of 77095344 - the child of 77095342
# 32038983_TG_T not found in gt_dv of 77095344 - the child of 77095342
# no 32038983_TG_T found in child
# []
# droping this variant, probably artefact
# 77095342
# check 32038997_TGG_T: HC - ['0|1', 0.1282051282051282, 39], DV - not called, Not found in bam
# need to check inheritance
# {'spouse': 77095343, 'child': 77095344}
# 32038997_TGG_T not found in gt_hc of 77095344 - the child of 77095342
# 32038997_TGG_T not found in gt_dv of 77095344 - the child of 77095342
# no 32038997_TGG_T found in child
# []
# droping this variant, probably artefact
# 77095342
# check 32039001_G_C: HC - ['0|1', 0.15384615384615385, 39], DV - not called, Not found in bam
# need to check inheritance
# {'spouse': 77095343, 'child': 77095344}
# 32039001_G_C not found in gt_hc of 77095344 - the child of 77095342
# 32039001_G_C not found in gt_dv of 77095344 - the child of 77095342
# no 32039001_G_C found in child
# []
# droping this variant, probably artefact
# 77095342
# check 32039002_G_A: HC - ['0|1', 0.15384615384615385, 39], DV - not called, Not found in bam
# need to check inheritance
# {'spouse': 77095343, 'child': 77095344}
# 32039002_G_A not found in gt_hc of 77095344 - the child of 77095342
# 32039002_G_A not found in gt_dv of 77095344 - the child of 77095342
# no 32039002_G_A found in child
# []
# droping this variant, probably artefact
# checking variants for 77095343
# checking variants for 77095344
# 77095344
# check 32039015_G_T: HC - ['1|0', 0.15384615384615385, 13], DV - not called, ['0/1', 0.3511705685618729, 897]
# HC genotype is supported by bam
# 32038514_C_T in 77095344 found in DV, but not in HC, checking it
# 32038514_C_T not called by HC, saving it with 0/1, ['0/1', 0.5012345679012346, 810]
# 32038844_A_C in 77095344 found in DV, but not in HC, checking it
# 32038844_A_C not called by HC, saving it with 0/1, ['0/1', 0.4449789536981359, 1663]
# 32038878_C_T in 77095344 found in DV, but not in HC, checking it
# 32038878_C_T not called by HC, saving it with 0/1, ['0/1', 0.49463135289906945, 1397]
# checking variants for 77095345
# checking variants for 77095346
# check 32038844_A_C: HC - ['1|0', 0.8571428571428571, 7], DV - 1/1, ['1/1', 0.8812580231065469, 1558]
# HC genotype is not supported by bam, saving a new genotype
# ['1/1', 0.8812580231065469, 1558]
# check 32038855_T_TTTG: HC - ['1|0', 0.3, 10], DV - 1/1, Not found in bam
# need to check inheritance
# {'sibling': 77095345}
# []
# droping this variant, probably artefact
# check 32038857_A_T: HC - ['1|0', 0.3, 10], DV - 1/1, ['1/1', 0.9518716577540107, 561]
# HC genotype is not supported by bam, saving a new genotype
# ['1/1', 0.9518716577540107, 561]
# 32038820_C_T in 77095346 found in DV, but not in HC, checking it
# 32038820_C_T not called by HC, saving it with 0/1, ['0/1', 0.4819976771196283, 1722]
# 32038855_T_TTTG in 77095346 found in DV, but not in HC, checking it
# low qual 32038855_T_TTTG in 77095346, checking inheritance; variant info: 1/1
# {'sibling': 77095345}
# []
# droping this variant, probably artefact
# 32038867_T_G in 77095346 found in DV, but not in HC, checking it
# 32038867_T_G not called by HC, saving it with 1/1, ['1/1', 0.9959839357429718, 1245]
# 32038878_C_T in 77095346 found in DV, but not in HC, checking it
# 32038878_C_T not called by HC, saving it with 1/1, ['1/1', 0.9943865276663993, 1247]
# 32038895_A_G in 77095346 found in DV, but not in HC, checking it
# 32038895_A_G not called by HC, saving it with 1/1, ['1/1', 0.9958333333333333, 1200]
# 32038903_A_G in 77095346 found in DV, but not in HC, checking it
# 32038903_A_G not called by HC, saving it with 1/1, ['1/1', 0.9991039426523297, 1116]
# 32038949_T_C in 77095346 found in DV, but not in HC, checking it
# 32038949_T_C not called by HC, saving it with 1/0, ['0/1', 0.6363636363636364, 44]
# checking variants for 77095347
# checking variants for 77095349
# checking variants for 77095350
# 77095350
# check 32038948_T_TC: HC - ['0|1', 0.15675675675675677, 185], DV - not called, Not found in bam
# need to check inheritance
# {'spouse': 77095347, 'child': 77095354}
# 32038948_T_TC not found in gt_hc of 77095354 - the child of 77095350
# 32038948_T_TC not found in gt_dv of 77095354 - the child of 77095350
# no 32038948_T_TC found in child
# []
# droping this variant, probably artefact
# 77095350
# check 32038949_T_G: HC - ['0|1', 0.15675675675675677, 185], DV - not called, Not found in bam
# need to check inheritance
# {'spouse': 77095347, 'child': 77095354}
# 32038949_T_G not found in gt_hc of 77095354 - the child of 77095350
# 32038949_T_G not found in gt_dv of 77095354 - the child of 77095350
# no 32038949_T_G found in child
# []
# droping this variant, probably artefact
# 77095350
# check 32038955_A_T: HC - ['0|1', 0.16111111111111112, 180], DV - not called, ['0/1', 0.2797281993204983, 883]
# HC genotype is supported by bam
# check 32039081_C_A: HC - ['1|1', 1.0, 21], DV - 1/0, bam - ['1/0', 0.5308720560152769, 1571]
# HC genotype is not supported by bam, saving a new genotype
# ['1/0', 0.5308720560152769, 1571]
# 32038878_C_T in 77095350 found in DV, but not in HC, checking it
# 32038878_C_T not called by HC, saving it with 0/1, ['0/1', 0.4304253785147801, 1387]
# 32039050_G_T in 77095350 found in DV, but not in HC, checking it
# 32039050_G_T not called by HC, saving it with 0/1, ['0/1', 0.4042402826855124, 1415]
# 32039056_A_G in 77095350 found in DV, but not in HC, checking it
# 32039056_A_G not called by HC, saving it with 0/1, ['0/1', 0.3830074173971679, 1483]
# 32039081_C_G in 77095350 found in DV, but not in HC, checking it
# 32039081_C_G not called by HC, saving it with 1/0, ['1/0', 0.46085295989815406, 1571]
# checking variants for 77095351
# checking variants for 77095352
# checking variants for 77095353
# checking variants for 77095354
# 32038855_T_TTTG in 77095354 found in DV, but not in HC, checking it
# low qual 32038855_T_TTTG in 77095354, checking inheritance; variant info: 0/1
# {'mother': 77095347, 'sibling': 77095349, 'father': 77095350}
# 32038855_T_TTTG not found in gt_hc of 77095347 - the mother of 77095354
# 32038855_T_TTTG not found in gt_dv of 77095347 - the mother of 77095354
# no 32038855_T_TTTG found in mother
# found 32038855_T_TTTG in 77095350 HC data - ['0|1', 0.23478260869565218, 115]
# 32038855_T_TTTG found in HC data of father
# found a heterozygote 32038855_T_TTTG in father with VAF 0.23478260869565218
# ['0|1']
# saving this variant even with bad QUAL
# 32038911_A_G in 77095354 found in DV, but not in HC, checking it
# 32038911_A_G not called by HC, saving it with 0/1, ['0/1', 0.4220110847189232, 1263]
# 32039020_G_A in 77095354 found in DV, but not in HC, checking it
# 32039020_G_A not called by HC, saving it with 0/1, ['0/1', 0.3322751322751323, 945]
# 32039027_C_A in 77095354 found in DV, but not in HC, checking it
# 32039027_C_A not called by HC, saving it with 1/0, ['1/0', 0.3713420787083754, 991]
# 32039046_A_G in 77095354 found in DV, but not in HC, checking it
# 32039046_A_G not called by HC, saving it with 0/1, ['0/1', 0.3666997026759167, 1009]
# 32039050_G_T in 77095354 found in DV, but not in HC, checking it
# 32039050_G_T not called by HC, saving it with 0/1, ['0/1', 0.3646944713870029, 1031]
# 32039081_C_G in 77095354 found in DV, but not in HC, checking it
# 32039081_C_G not called by HC, saving it with 1/0, ['1/0', 0.40606060606060607, 1155]
# 32039109_G_A in 77095354 found in DV, but not in HC, checking it
# 32039109_G_A not called by HC, saving it with 0/1, ['0/1', 0.3791304347826087, 1150]
# checking variants for 77095355
# checking variants for 77095356
# checking variants for 77095357
# checking variants for 77095358
# checking variants for 77095359
# checking variants for 77095360
# checking variants for 77095361
# checking variants for 77095362
# checking variants for 77095363
# checking variants for 77095364
# checking variants for 77095365
# checking variants for 77095366
# checking variants for 77095367
# checking variants for 77095368
# checking variants for 77095373
# checking variants for 77095374
# checking variants for 77095375
# checking variants for 77095376
# checking variants for 77095377
# checking variants for 77095378
# checking variants for 77095379
# checking variants for 77095380
# checking variants for 77095381
# checking variants for 77095382
# checking variants for 77095383
# checking variants for 77095384
# 32039081_C_G in 77095384 found in DV, but not in HC, checking it
# 32039081_C_G not called by HC, saving it with 1/1, ['1/1', 0.9991769547325103, 1215]
# checking variants for 77095385
# checking variants for 77095386
# checking variants for 77095387
# checking variants for 77095388
# checking variants for 77095389
# checking variants for 77095390

# %%
trios[77092370]
# Out:
# {'father': 77092368, 'mother': 77092371}

# %%
print(gt_hc[77092370]['32038949_T_G'], 'NONE', gt_dv[77092370]['32038949_T_G'], gt_dv[77092370]['32038949_T_C'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/miniforge3/envs/haplotypes/lib/python3.12/site-packages/IPython/core/async_helpers.py:128, in _pseudo_sync_runner(coro)
#     120 """
#     121 A runner that does not really allow async execution, and just advance the coroutine.
#     122
#    (...)    125 Credit to Nathaniel Smith
#     126 """
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#     130     return exc.value
#
# File ~/miniforge3/envs/haplotypes/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3256, in InteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3254 if store_history:
#    3255     assert self.history_manager is not None
# -> 3256     self.history_manager.store_inputs(self.execution_count, cell, raw_cell)
#    3257 if not silent:
#    3258     self.logger.log(cell, raw_cell)
#
# File ~/miniforge3/envs/haplotypes/lib/python3.12/site-packages/IPython/core/history.py:951, in HistoryManager.store_inputs(self, line_num, source, source_raw)
#     948 self.input_hist_parsed.append(source)
#     949 self.input_hist_raw.append(source_raw)
# --> 951 with self.db_input_cache_lock:
#     952     self.db_input_cache.append((line_num, source, source_raw))
#     953     # Trigger to flush cache and write to DB.
#
# KeyboardInterrupt:

# %%
gt_bam[77092898]
# Out:
# {'32038115_G_C': ['1/1', 0.9778085991678225, 1442],
#  '32038127_T_C': ['1/1', 0.9961180124223602, 1288],
#  '32038128_A_C': ['1/1', 0.9992223950233281, 1286],
#  '32038139_A_G': ['1/1', 0.996177370030581, 1308],
#  '32038141_T_G': ['1/1', 1.0, 1365],
#  '32038213_T_C': ['1/1', 0.9944328462073765, 1437],
#  '32038224_C_T': ['1/1', 0.996395097332372, 1387],
#  '32038297_C_T': ['1/1', 0.9927826784282278, 1247],
#  '32038310_G_A': ['1/1', 0.9694589877835951, 1146],
#  '32038313_T_C': ['1/1', 1.0, 1117],
#  '32038320_A_G': ['1/1', 0.9873843566021867, 1189],
#  '32038419_C_T': ['1/1', 0.9975339087546239, 811],
#  '32038514_C_T': ['1/1', 0.9549653579676675, 866],
#  '32038844_A_C': ['1/1', 0.8655083655083655, 1554],
#  '32038857_A_T': ['1/1', 0.9485294117647058, 544],
#  '32038867_T_G': ['1/1', 0.9952076677316294, 1252],
#  '32038878_C_T': ['1/1', 0.9951923076923077, 1248],
#  '32038895_A_G': ['1/1', 0.9974619289340102, 1182],
#  '32038903_A_G': ['1/1', 0.9982062780269059, 1115],
#  '32038911_A_G': ['1/1', 0.9943872778297475, 1069],
#  '32038927_A_G': ['1/1', 0.9979338842975206, 968],
#  '32038938_T_G': ['1/1', 0.9988479262672811, 868],
#  '32038949_T_C': ['0/1', 0.7575757575757576, 33],
#  '32038955_A_T': ['1/1', 1.0, 481],
#  '32038971_C_A': ['1/1', 0.874828060522696, 727],
#  '32038998_G_T': ['1/1', 1.0, 16],
#  '32038999_G_C': ['1/1', 1.0, 17],
#  '32039001_G_C': ['1/1', 0.9280575539568345, 278],
#  '32039002_G_A': ['1/1', 0.925, 280],
#  '32039015_G_T': ['1/1', 0.8982785602503912, 639],
#  '32039020_G_A': ['1/1', 0.9498567335243553, 698],
#  '32039027_C_A': ['1/1', 0.9505882352941176, 850],
#  '32039046_A_G': ['1/1', 1.0, 907],
#  '32039050_G_T': ['1/1', 1.0, 905],
#  '32039055_C_G': ['1/1', 1.0, 909],
#  '32039056_A_G': ['1/1', 0.9988925802879292, 903],
#  '32039081_C_G': ['1/1', 0.9925925925925926, 1080],
#  '32039109_G_A': ['1/1', 0.9621676891615542, 978],
#  '32039128_C_G': ['1/1', 0.9812889812889813, 481],
#  '32039143_C_T': ['1/1', 0.76, 225],
#  '32039847_A_G': ['1/1', 0.9990272373540856, 1028],
#  '32039848_C_T': ['1/1', 0.9950884086444007, 1018],
#  '32040013_C_G': ['1/1', 0.9963369963369964, 819],
#  '32040110_G_T': ['1/1', 0.9990990990990991, 1110],
#  '32041186_C_T': ['1/1', 0.9588414634146342, 656]}

# %%
res = defaultdict(dict)
for idx, row in files_list.iterrows():
    # dv
    vcf = read_vcf(row['dv'], mode = 'dv')
    vcf = vcf[vcf['FILTER'] == 'PASS']
    vcf = vcf[(vcf['POS'] >= calling_region[0]) & (vcf['POS'] <= calling_region[1])]
    sample_dv=gt_vectors(vcf, mode = 'dv')
    # hc 
    vcf = read_vcf(row['hc'], mode='hc')
    vcf = vcf[(vcf['POS'] >= calling_region[0]) & (vcf['POS'] <= calling_region[1])]
    sample_hc=gt_vectors(vcf, mode= 'hc')

    #pileup
    vcf = read_vcf(row['pileup'], mode='bam')
    vcf = vcf[(vcf['POS'] >= calling_region[0]) & (vcf['POS'] <= calling_region[1])]
    sample_pp=gt_vectors(vcf, mode= 'dv')

    for position in sample_hc.keys():
        hc_value=sample_hc[position][0]
        if position in sample_dv.keys():
            dv_value=sample_dv[position][0]
            res[idx][position] = check_variant(idx, position, hc_value, dv_value, sample_hc, sample_dv, trios, gt_hc, gt_dv)
        else:
            hc_value=sample_hc[position][0]
            hc=hc_value.split('|')
            hc=int(hc[0])+int(hc[1])
            if hc == 2:
                if sample_hc[position][1]>0.85 and sample_hc[position][2]>=30:
                    # print(f'{position} not called by DV, saving it with {hc_value}, {sample_hc[position][1]}, {sample_hc[position][2]}')
                    res[idx][position] = hc_value
                else:
                    print(f'low qual {position} in {idx}, checking inheritance; variant info: {hc_value}, {sample_hc[position][1]}, {sample_hc[position][2]}')
                    inheritance = check_inheritance(idx, position, trios, gt_hc, gt_dv)
                    if inheritance == True:
                        print('saving this variant even with bad QUAL')
                        res[idx][position] = hc_value
                    else:
                        print('droping this variant, probably artefact')
            if hc == 1:
                if (sample_hc[position][1] >= 0.2 and sample_hc[position][1] < 0.85) and sample_hc[position][2]>=30:
                    # print(f'{position} not called by DV, saving it with {hc_value}, {sample_hc[position][1]}, {sample_hc[position][2]}')
                    res[idx][position] = hc_value
                else:
                    print(f'low qual {position} in {idx}, checking inheritance; variant info: {hc_value}, {sample_hc[position][1]}, {sample_hc[position][2]}')
                    inheritance = check_inheritance(idx, position, trios, gt_hc, gt_dv)
                    if inheritance == True:
                        print('saving this variant even with bad QUAL')
                        res[idx][position] = hc_value
                    else:
                        print('droping this variant, probably artefact')
    for position in sample_dv.keys():
        if position not in res[idx].keys():
            dv_value=sample_dv[position][0]
            dv=dv_value.split('/')
            dv=int(dv[0])+int(dv[1])
            if dv == 2:
                if sample_dv[position][1]> 0.85 and sample_dv[position][2]>=30:
                    # print(f'{position} not called by HC, saving it with {dv_value}, {sample_dv[position][1]}, {sample_dv[position][2]}')
                    res[idx][position] = dv_value
                else:
                    print(f'low qual {position} in {idx}, checking inheritance; variant info: {dv_value}, {sample_dv[position][1]}, {sample_dv[position][2]}')
                    inheritance = check_inheritance(idx, position, trios, gt_hc, gt_dv)
                    if inheritance == True:
                        print('saving this variant even with bad QUAL')
                        res[idx][position] = dv_value
                    else:
                        print('droping this variant, probably artefact')
            if dv == 1:
                if (sample_dv[position][1] >= 0.2 and sample_dv[position][1] < 0.85) and sample_dv[position][2]>=30:
                    # print(f'{position} not called by HC, saving it with {dv_value}, {sample_dv[position][1]}, {sample_dv[position][2]}')
                    res[idx][position] = dv_value
                else:
                    print(f'low qual {position} in {idx}, checking inheritance; variant info: {dv_value}, {sample_dv[position][1]}, {sample_dv[position][2]}')
                    inheritance = check_inheritance(idx, position, trios, gt_hc, gt_dv)
                    if inheritance == True:
                        print('saving this variant even with bad QUAL')
                        res[idx][position] = dv_value
                    else:
                        print('droping this variant, probably artefact')
# Out:
# for 77092312 comparing 32038855_T_TTTG with HC - 1|0 and DV - 1/1
# hc right with 1|0, VAF - 0.8401396160558464, DP-2868
# low qual 32038855_T_TTG in 77092312, checking inheritance; variant info: 1|0, 0.15986038394415358, 2868
# {'mother': 77092311, 'sibling': 77092313}
# 32038855_T_TTG not found in gt_hc of 77092311 - the mother of 77092312
# 32038855_T_TTG not found in gt_dv of 77092311 - the mother of 77092312
# no 32038855_T_TTG found in mother
# []
# droping this variant, probably artefact
# low qual 32038855_T_TTG in 77092329, checking inheritance; variant info: 1|0, 0.18454661558109833, 1581
# {'mother': 77092327}
# 32038855_T_TTG not found in gt_hc of 77092327 - the mother of 77092329
# 32038855_T_TTG not found in gt_dv of 77092327 - the mother of 77092329
# no 32038855_T_TTG found in mother
# []
# droping this variant, probably artefact
# for 77092329 comparing 32038855_T_TTTG with HC - 1|0 and DV - 1/1
# hc right with 1|0, VAF - 0.8154533844189017, DP-1581
# for 77092370 comparing 32038855_T_TTTG with HC - 1|0 and DV - 1/1
# hc right with 1|0, VAF - 0.6842105263157895, DP-96
# for 77092370 comparing 32038949_T_G with HC - 1|1 and DV - 1/0
# dv right with 1/0, VAF - 0.8, DP-168
# for 77092370 comparing 32038962_A_ATCC with HC - 0|1 and DV - 1/1
# dv right with 1/1, VAF - 0.9246575342465754, DP-146
# low qual 32039001_G_C in 77092370, checking inheritance; variant info: 1|1, 1.0, 13
# {'father': 77092368, 'mother': 77092371}
# found 32039001_G_C in 77092368 HC data - ['1|0', 0.5068493150684932, 73]
# 32039001_G_C found only in HC data of father
# found a heterozygote 32039001_G_C in father with VAF 0.5068493150684932
# found 32039001_G_C in 77092371 HC data - ['1|0', 0.4712892741061755, 2769]
# 32039001_G_C found only in HC data of mother
# found a heterozygote 32039001_G_C in mother with VAF 0.4712892741061755
# ['1|0', '1|0']
# saving this variant even with bad QUAL
# low qual 32039006_G_A in 77092377, checking inheritance; variant info: 0|1, 0.16883116883116883, 77
# {'mother': 77092375, 'sibling': 77092376}
# 32039006_G_A not found in gt_hc of 77092375 - the mother of 77092377
# 32039006_G_A not found in gt_dv of 77092375 - the mother of 77092377
# no 32039006_G_A found in mother
# []
# droping this variant, probably artefact
# low qual 32039007_A_AAG in 77092384, checking inheritance; variant info: 1|0, 0.75, 20
# {'child': 77092383, 'spouse': 77092386}
# found 32039007_A_AAG in 77092383 HC data - ['0|1', 0.6153846153846154, 130]
# 32039007_A_AAG found only in HC data of child
# found a heterozygote 32039007_A_AAG in child with VAF 0.6153846153846154
# ['0|1']
# saving this variant even with bad QUAL
# low qual 32039015_G_T in 77092384, checking inheritance; variant info: 1|0, 0.75, 20
# {'child': 77092383, 'spouse': 77092386}
# found 32039015_G_T in 77092383 HC data - ['0|1', 0.5894039735099338, 151]
# 32039015_G_T found only in HC data of child
# found a heterozygote 32039015_G_T in child with VAF 0.5894039735099338
# ['0|1']
# saving this variant even with bad QUAL
# low qual 32039020_G_A in 77092384, checking inheritance; variant info: 1|0, 0.75, 20
# {'child': 77092383, 'spouse': 77092386}
# found 32039020_G_A in 77092383 HC data - ['0|1', 0.5947712418300654, 153]
# 32039020_G_A found only in HC data of child
# found a heterozygote 32039020_G_A in child with VAF 0.5947712418300654
# ['0|1']
# saving this variant even with bad QUAL
# low qual 32039046_A_G in 77092384, checking inheritance; variant info: 1|0, 0.8666666666666667, 15
# {'child': 77092383, 'spouse': 77092386}
# found 32039046_A_G in 77092383 HC data - ['0|1', 0.553072625698324, 179]
# checking relative variant with ['0|1', 0.553072625698324, 179] AND ['0/1', 0.47282608695652173, 184]
# found 32039046_A_G in child with genotype 0|1
# ['0|1']
# saving this variant even with bad QUAL
# low qual 32039050_G_T in 77092384, checking inheritance; variant info: 1|0, 0.6071428571428571, 28
# {'child': 77092383, 'spouse': 77092386}
# found 32039050_G_T in 77092383 HC data - ['0|1', 0.4327731092436975, 238]
# 32039050_G_T found only in HC data of child
# found a heterozygote 32039050_G_T in child with VAF 0.4327731092436975
# ['0|1']
# saving this variant even with bad QUAL
# low qual 32039056_A_G in 77092384, checking inheritance; variant info: 1|0, 0.6206896551724138, 29
# {'child': 77092383, 'spouse': 77092386}
# found 32039056_A_G in 77092383 HC data - ['0|1', 0.43983402489626555, 241]
# checking relative variant with ['0|1', 0.43983402489626555, 241] AND ['0/1', 0.4189189189189189, 222]
# found 32039056_A_G in child with genotype 0|1
# ['0|1']
# saving this variant even with bad QUAL
# for 77092388 comparing 32038855_T_TTTG with HC - 1|0 and DV - 1/1
# hc right with 1|0, VAF - 0.8064516129032258, DP-97
# low qual 32038855_T_TTG in 77092388, checking inheritance; variant info: 1|0, 0.1935483870967742, 97
# {'mother': 77092391, 'sibling': 77092392, 'father': 77092389}
# 32038855_T_TTG not found in gt_hc of 77092391 - the mother of 77092388
# 32038855_T_TTG not found in gt_dv of 77092391 - the mother of 77092388
# no 32038855_T_TTG found in mother
# 32038855_T_TTG not found in gt_hc of 77092389 - the father of 77092388
# 32038855_T_TTG not found in gt_dv of 77092389 - the father of 77092388
# no 32038855_T_TTG found in father
# []
# droping this variant, probably artefact
# for 77092388 comparing 32038949_T_G with HC - 1|1 and DV - 1/0
# hc right with 1|1, VAF - 1.0, DP-161
# low qual 32038949_T_C in 77092388, checking inheritance; variant info: 1/0, 0.1724137931034483, 146
# {'mother': 77092391, 'sibling': 77092392, 'father': 77092389}
# 32038949_T_C not found in gt_hc of 77092391 - the mother of 77092388
# 32038949_T_C not found in gt_dv of 77092391 - the mother of 77092388
# no 32038949_T_C found in mother
# 32038949_T_C not found in gt_hc of 77092389 - the father of 77092388
# 32038949_T_C not found in gt_dv of 77092389 - the father of 77092388
# no 32038949_T_C found in father
# []
# droping this variant, probably artefact
# low qual 32038855_T_TTG in 77092392, checking inheritance; variant info: 1|0, 0.1889763779527559, 129
# {'mother': 77092391, 'sibling': 77092388, 'father': 77092389}
# 32038855_T_TTG not found in gt_hc of 77092391 - the mother of 77092392
# 32038855_T_TTG not found in gt_dv of 77092391 - the mother of 77092392
# no 32038855_T_TTG found in mother
# 32038855_T_TTG not found in gt_hc of 77092389 - the father of 77092392
# 32038855_T_TTG not found in gt_dv of 77092389 - the father of 77092392
# no 32038855_T_TTG found in father
# []
# droping this variant, probably artefact
# for 77092392 comparing 32038855_T_TTTG with HC - 1|0 and DV - 1/1
# hc right with 1|0, VAF - 0.
comparing 32038855_T_TTTG with HC - 1|0 and DV - 1/1
# hc right with 1|0, VAF - 0.816017316017316, DP-1871
# low qual 32038855_T_TTG in 77092436, checking inheritance; variant info: 1|0, 0.17109634551495018, 1214
# {'father': 77092438, 'mother': 77092437}
# 32038855_T_TTG not found in gt_hc of 77092438 - the father of 77092436
# 32038855_T_TTG not found in gt_dv of 77092438 - the father of 77092436
# no 32038855_T_TTG found in father
# 32038855_T_TTG not found in gt_hc of 77092437 - the mother of 77092436
# 32038855_T_TTG not found in gt_dv of 77092437 - the mother of 77092436
# no 32038855_T_TTG found in mother
# []
# droping this variant, probably artefact
# for 77092436 comparing 32038855_T_TTTG with HC - 1|0 and DV - 1/1
# hc right with 1|0, VAF - 0.8289036544850499, DP-1214
# low qual 32038878_C_T in 77092437, checking inheritance; variant info: 0|1, 0.17341040462427745, 519
# {'spouse': 77092438, 'child': 77092436}
# found 32038878_C_T in 77092436 HC data - ['1|1', 0.9966969446738233, 1211]
# checking relative variant with ['1|1', 0.9966969446738233, 1211] AND ['1/1', 1.0, 271]
# found 32038878_C_T in child with genotype 1|1
# ['1|1']
# saving this variant even with bad QUAL
# low qual 32038895_A_G in 77092437, checking inheritance; variant info: 0|1, 0.14285714285714285, 469
# {'spouse': 77092438, 'child': 77092436}
# found 32038895_A_G in 77092436 HC data - ['1|1', 1.0, 1161]
# checking relative variant with ['1|1', 1.0, 1161] AND ['1/1', 1.0, 261]
# found 32038895_A_G in child with genotype 1|1
# ['1|1']
# saving this variant even with bad QUAL
# low qual 32038855_T_TTG in 77092450, checking inheritance; variant info: 1|0, 0.17721518987341772, 2449
# {'mother': 77092449, 'father': 77092448}
# 32038855_T_TTG not found in gt_hc of 77092449 - the mother of 77092450
# 32038855_T_TTG not found in gt_dv of 77092449 - the mother of 77092450
# no 32038855_T_TTG found in mother
# 32038855_T_TTG not found in gt_hc of 77092448 - the father of 77092450
# 32038855_T_TTG not found in gt_dv of 77092448 - the father of 77092450
# no 32038855_T_TTG found in father
# []
# droping this variant, probably artefact
# for 77092450 comparing 32038855_T_TTTG with HC - 1|0 and DV - 1/1
# hc right with 1|0, VAF - 0.8227848101265823, DP-2449
# low qual 32038855_T_TTG in 77092472, checking inheritance; variant info: 1|0, 0.16150576806314512, 1661
# {'mother': 77092473, 'father': 77092474}
# 32038855_T_TTG not found in gt_hc of 77092473 - the mother of 77092472
# 32038855_T_TTG not found in gt_dv of 77092473 - the mother of 77092472
# no 32038855_T_TTG found in mother
# 32038855_T_TTG not found in gt_hc of 77092474 - the father of 77092472
# 32038855_T_TTG not found in gt_dv of 77092474 - the father of 77092472
# no 32038855_T_TTG found in father
# []
# droping this variant, probably artefact
# low qual 32038855_T_TTG in 77092500, checking inheritance; variant info: 1|0, 0.18298653610771115, 1639
# {'mother': 77092501, 'father': 77092502}
# 32038855_T_TTG not found in gt_hc of 77092501 - the mother of 77092500
# 32038855_T_TTG not found in gt_dv of 77092501 - the mother of 77092500
# no 32038855_T_TTG found in mother
# 32038855_T_TTG not found in gt_hc of 77092502 - the father of 77092500
# 32038855_T_TTG not found in gt_dv of 77092502 - the father of 77092500
# no 32038855_T_TTG found in father
# []
# droping this variant, probably artefact
# for 77092500 comparing 32038855_T_TTTG with HC - 1|0 and DV - 1/1
# hc right with 1|0, VAF - 0.8170134638922889, DP-1639
# low qual 32038903_A_G in 77092529, checking inheritance; variant info: 0|1, 0.12, 25
# {'spouse': 77092530, 'child': 77092531}
# 32038903_A_G not found in gt_hc of 77092531 - the child of 77092529
# found 32038903_A_G in 77092531 DV data - ['1/1', 1.0, 137]
# 32038903_A_G found only in DV data of child
# found a homozygote 32038903_A_G in child with VAF 1.0
# found only low qual 32038903_A_G in child with 1.0 and 137, probably an artefact
# ['1/1']
# saving this variant even with bad QUAL
# low qual 32038948_T_TC in 77092529, checking inheritance; variant info: 0|1, 0.18518518518518517, 27
# {'spouse': 77092530, 'child': 77092531}
# 32038948_T_TC not found in gt_hc of 77092531 - the child of 77092529
# found 32038948_T_TC in 77092531 DV data - ['1/1', 0.9016393442622951, 61]
# 32038948_T_TC found only in DV data of child
# found a homozygote 32038948_T_TC in child with VAF 0.9016393442622951
# found only low qual 32038948_T_TC in child with 0.9016393442622951 and 61, probably an artefact
# ['1/1']
# saving this variant even with bad QUAL
# low qual 32038949_T_G in 77092529, checking inheritance; variant info: 0|1, 0.17857142857142858, 28
# {'spouse': 77092530, 'child': 77092531}
# 32038949_T_G not found in gt_hc of 77092531 - the child of 77092529
# found 32038949_T_G in 77092531 DV data - ['1/1', 1.0, 55]
# 32038949_T_G found only in DV data of child
# found a homozygote 32038949_T_G in child with VAF 1.0
# found only low qual 32038949_T_G in child with 1.0 and 55, probably an artefact
# ['1/1']
# saving this variant even with bad QUAL
# low qual 32038955_A_T in 77092529, checking inheritance; variant info: 0|1, 0.16666666666666666, 30
# {'spouse': 77092530, 'child': 77092531}
# 32038955_A_T not found in gt_hc of 77092531 - the child of 77092529
# found 32038955_A_T in 77092531 DV data - ['1/1', 1.0, 59]
# 32038955_A_T found only in DV data of child
# found a homozygote 32038955_A_T in child with VAF 1.0
# found only low qual 32038955_A_T in child with 1.0 and 59, probably an artefact
# ['1/1']
# saving this variant even with bad QUAL
# low qual 32038962_A_ATCC in 77092529, checking inheritance; variant info: 0|1, 0.19230769230769232, 26
# {'spouse': 77092530, 'child': 77092531}
# 32038962_A_ATCC not found in gt_hc of 77092531 - the child of 77092529
# found 32038962_A_ATCC in 77092531 DV data - ['1/1', 0.9333333333333333, 60]
# 32038962_A_ATCC found only in DV data of child
# found a homozygote 32038962_A_ATCC in child with VAF 0.9333333333333333
# found only low qual 32038962_A_ATCC in child with 0.9333333333333333 and 60, probably an artefact
# ['1/1']
# saving this variant even with bad QUAL
# low qual 32038971_C_A in 77092529, checking inheritance; variant info: 0|1, 0.19230769230769232, 26
# {'spouse': 77092530, 'child': 77092531}
# 32038971_C_A not found in gt_hc of 77092531 - the child of 77092529
# found 32038971_C_A in 77092531 DV data - ['1/1', 0.875, 88]
# 32038971_C_A found only in DV data of child
# found a homozygote 32038971_C_A in child with VAF 0.875
# found only low qual 32038971_C_A in child with 0.875 and 88, probably an artefact
# ['1/1']
# saving this variant even with bad QUAL
# low qual 32038983_TG_T in 77092529, checking inheritance; variant info: 0|1, 0.125, 24
# {'spouse': 77092530, 'child': 77092531}
# 32038983_TG_T not found in gt_hc of 77092531 - the child of 77092529
# 32038983_TG_T not found in gt_dv of 77092531 - the child of 77092529
# no 32038983_TG_T found in child
# []
# droping this variant, probably artefact
# low qual 32038997_TGG_T in 77092529, checking inheritance; variant info: 0|1, 0.11538461538461539, 26
# {'spouse': 77092530, 'child': 77092531}
# 32038997_TGG_T not found in gt_hc of 77092531 - the child of 77092529
# 32038997_TGG_T not found in gt_dv of 77092531 - the child of 77092529
# no 32038997_TGG_T found in child
# []
# droping this variant, probably artefact
# low qual 32039001_G_C in 77092529, checking inheritance; variant info: 0|1, 0.125, 24
# {'spouse': 77092530, 'child': 77092531}
# 32039001_G_C not found in gt_hc of 77092531 - the child of 77092529
# 32039001_G_C not found in gt_dv of 77092531 - the child of 77092529
# no 32039001_G_C found in child
# []
# droping this variant, probably artefact
# low qual 32039002_G_A in 77092529, checking inheritance; variant info: 0|1, 0.125, 24
# {'spouse': 77092530, 'child': 77092531}
# 32039002_G_A not found in gt_hc of 77092531 - the child of 77092529
# found 32039002_G_A in 77092531 DV data - ['1/1', 0.9487179487179487, 39]
# 32039002_G_A found only in DV data of child
# found a homozygote 32039002_G_A in child with VAF 0.9487179487179487
# found only low qual 32039002_G_A in child with 0.9487179487179487 and 39, probably an artefact
# ['1/1']
# saving this variant even with bad QUAL
# low qual 32039007_A_AAG in 77092529, checking inheritance; variant info: 0|1, 0.24, 25
# {'spouse': 77092530, 'child': 77092531}
# 32039007_A_AAG not found in gt_hc of 77092531 - the child of 77092529
# 32039007_A_AAG not found in gt_dv of 77092531 - the child of 77092529
# no 32039007_A_AAG found in child
# []
# droping this variant, probably artefact
# low qual 32039015_G_T in 77092529, checking inheritance; variant info: 0|1, 0.24, 25
# {'spouse': 77092530, 'child': 77092531}
# 32039015_G_T not found in gt_hc of 77092531 - the child of 77092529
# found 32039015_G_T in 77092531 DV data - ['1/1', 0.9270833333333334, 96]
# 32039015_G_T found only in DV data of child
# found a homozygote 32039015_G_T in child with VAF 0.9270833333333334
# found only low qual 32039015_G_T in child with 0.9270833333333334 and 96, probably an artefact
# ['1/1']
# saving this variant even with bad QUAL
# low qual 32039020_G_A in 77092529, checking inheritance; variant info: 0|1, 0.2608695652173913, 23
# {'spouse': 77092530, 'child': 77092531}
# 32039020_G_A not found in gt_hc of 77092531 - the child of 77092529
# 32039020_G_A not found in gt_dv of 77092531 - the child of 77092529
# no 32039020_G_A found in child
# []
# droping this variant, probably artefact
# low qual 32039027_C_A in 77092529, checking inheritance; variant info: 0|1, 0.2727272727272727, 22
# {'spouse': 77092530, 'child': 77092531}
# 32039027_C_A not found in gt_hc of 77092531 - the child of 77092529
# found 32039027_C_A in 77092531 DV data - ['1/1', 0.9495798319327731, 119]
# 32039027_C_A found only in DV data of child
# found a homozygote 32039027_C_A in child with VAF 0.9495798319327731
# found only low qual 32039027_C_A in child with 0.9495798319327731 and 119, probably an artefact
# ['1/1']
# saving this variant even with bad QUAL
# low qual 32039046_A_G in 77092529, checking inheritance; variant info: 0|1, 0.3076923076923077, 26
# {'spouse': 77092530, 'child': 77092531}
# 32039046_A_G not found in gt_hc of 77092531 - the child of 77092529
# found 32039046_A_G in 77092531 DV data - ['1/1', 0.9921875, 128]
# 32039046_A_G found only in DV data of child
# found a homozygote 32039046_A_G in child with VAF 0.9921875
# found only low qual 32039046_A_G in child with 0.9921875 and 128, probably an artefact
# ['1/1']
# saving this variant even with bad QUAL
# low qual 32038983_TG_T in 77092530, checking inheritance; variant info: 0|1, 0.1875, 32
# {'spouse': 77092529, 'child': 77092531}
# 32038983_TG_T not found in gt_hc of 77092531 - the child of 77092530
# 32038983_TG_T not found in gt_dv of 77092531 - the child of 77092530
# no 32038983_TG_T found in child
# []
# droping this variant, probably artefact
# for 77092531 comparing 32038139_A_G with HC - 1|0 and DV - 1/1
# dv right with 1/1, VAF - 0.9793103448275862, DP-145
# for 77092531 comparing 32038141_T_G with HC - 1|0 and DV - 1/1
# dv right with 1/1, VAF - 0.9741935483870968, DP-155
# for 77092531 comparing 32038844_A_C with HC - 1|0 and DV - 1/1
# both wrong, checking inheritance; variant info: 1|0, 0.38461538461538464, 13 AND 1/1, 0.8266666666666667, 225
# {'father': 77092530, 'mother': 77092529}
# found 32038844_A_C in 77092530 HC data - ['1|1', 0.9821428571428571, 112]
# checking relative variant with ['1|1', 0.9821428571428571, 112] AND ['1/1', 0.8554216867469879, 249]
# found 32038844_A_C in father with genotype 1|1
# found 32038844_A_C in 77092529 HC data - ['0|1', 0.3813559322033898, 118]
# checking relative variant with ['0|1', 0.3813559322033898, 118] AND ['0/1', 0.33884297520661155, 242]
# found 32038844_A_C in mother with genotype 0|1
# ['1|1', '0|1']
# saving this variant even with bad QUAL
# low qual 32038847_A_ATTT in 77092531, checking inheritance; variant info: 1|1, 0.8, 10
# {'father': 77092530, 'mother': 77092529}
# 32038847_A_ATTT not found in gt_hc of 77092530 - the father of 77092531
# 32038847_A_ATTT not found in gt_dv of 77092530 - the father of 77092531
# no 32038847_A_ATTT found in father
# 32038847_A_ATTT not found in gt_hc of 77092529 - the mother of 77092531
# 32038847_A_ATTT not found in gt_dv of 77092529 - the mother of 77092531
# no 32038847_A_ATTT found in mother
# []
# droping this variant, probably artefact
# low qual 32039081_C_A in 77092531, checking inheritance; variant info: 1|1, 1.0, 9
# {'father': 77092530, 'mother': 77092529}
# found 32039081_C_A in 77092530 HC data - ['1|0', 0.5331325301204819, 332]
# checking relative variant with ['1|0', 0.5331325301204819, 332] AND ['1/0', 0.5821917808219178, 146]
# found 32039081_C_A in father with genotype 1|0
# found 32039081_C_A in 77092529 HC data - ['1|0', 0.8709677419354839, 93]
# checking relative variant with ['1|0', 0.8709677419354839, 93] AND ['1/0', 0.5384615384615384, 144]
# found 32039081_C_A in mother with genotype 1|0
# ['1|0', '1|0']
# saving this variant even with bad QUAL
# low qual 32038855_T_TTTG in 77092531, checking inheritance; variant info: 1/1, 0.4639175257731959, 194
# {'father': 77092530, 'mother': 77092529}
# found 32038855_T_TTTG in 77092530 HC data - ['0|1', 0.40540540540540543, 111]
# checking relative variant with ['0|1', 0.40540540540540543, 111] AND ['1/0', 0.7575757575757576, 241]
# found 32038855_T_TTTG in father with genotype 0|1
# found 32038855_T_TTTG in 77092529 HC data - ['0|1', 0.3805309734513274, 113]
# 32038855_T_TTTG found only in HC data of mother
# found a heterozygote 32038855_T_TTTG in mother with VAF 0.3805309734513274
# ['0|1', '0|1']
# saving this variant even with bad QUAL
# for 77092537 comparing 32038855_T_TTTG with HC - 1|0 and DV - 1/1
# hc right with 1|0, VAF - 0.8281437125748503, DP-1682
# low qual 32038855_T_TTG in 77092537, checking inheritance; variant info: 1|0, 0.1718562874251497, 1682
# {'mother': 77092536, 'father': 77092535}
# 32038855_T_TTG not found in gt_hc of 77092536 - the mother of 77092537
# 32038855_T_TTG not found in gt_dv of 77092536 - the mother of 77092537
# no 32038855_T_TTG found in mother
# 32038855_T_TTG not found in gt_hc of 77092535 - the father of 77092537
# 32038855_T_TTG not found in gt_dv of 77092535 - the father of 77092537
# no 32038855_T_TTG found in father
# []
# droping this variant, probably artefact
# for 77092543 comparing 32038855_T_TTTG with HC - 1|0 and DV - 1/1
# hc right with 1|0, VAF - 0.8343023255813954, DP-700
# low qual 32038855_T_TTG in 77092543, checking inheritance; variant info: 1|0, 0.16569767441860464, 700
# {'mother': 77092542, 'father': 77092541}
# 32038855_T_TTG not found in gt_hc of 77092542 - the mother of 77092543
# 32038855_T_TTG not found in gt_dv of 77092542 - the mother of 77092543
# no 32038855_T_TTG found in mother
# 32038855_T_TTG not found in gt_hc of 77092541 - the father of 77092543
# 32038855_T_TTG not found in gt_dv of 77092541 - the father of 77092543
# no 32038855_T_TTG found in father
# []
# droping this variant, probably artefact
# low qual 32038971_C_A in 77092563, checking inheritance; variant info: 1|0, 0.41379310344827586, 29
# {'sibling': 77092564, 'mother': 77092565}
# 32038971_C_A not found in gt_hc of 77092565 - the mother of 77092563
# 32038971_C_A not found in gt_dv of 77092565 - the mother of 77092563
# no 32038971_C_A found in mother
# []
# droping this variant, probably artefact
# low qual 32038983_TG_T in 77092563, checking inheritance; variant info: 1|0, 0.45454545454545453, 22
# {'sibling': 77092564, 'mother': 77092565}
# 32038983_TG_T not found in gt_hc of 77092565 - the mother of 77092563
# 32038983_TG_T not found in gt_dv of 77092565 - the mother of 77092563
# no 32038983_TG_T found in mother
# []
# droping this variant, probably artefact
# low qual 32038997_TGG_T in 77092563, checking inheritance; variant info: 1|0, 0.6071428571428571, 28
# {'sibling': 77092564, 'mother': 77092565}
# 32038997_TGG_T not found in gt_hc of 77092565 - the mother of 77092563
# 32038997_TGG_T not found in gt_dv of 77092565 - the mother of 77092563
# no 32038997_TGG_T found in mother
# []
# droping this variant, probably artefact
# low qual 32039001_G_C in 77092563, checking inheritance; variant info: 1|0, 0.5862068965517241, 29
# {'sibling': 77092564, 'mother': 77092565}
# 32039001_G_C not found in gt_hc of 77092565 - the mother of 77092563
# 32039001_G_C not found in gt_dv of 77092565 - the mother of 77092563
# no 32039001_G_C found in mother
# []
# droping this variant, probably artefact
# low qual 32039002_G_A in 77092563, checking inheritance; variant info: 1|0, 0.5862068965517241, 29
# {'sibling': 77092564, 'mother': 77092565}
# 32039002_G_A not found in gt_hc of 77092565 - the mother of 77092563
# 32039002_G_A not found in gt_dv of 77092565 - the mother of 77092563
# no 32039002_G_A found in mother
# []
# droping this variant, probably artefact
# low qual 32038948_T_TC in 77092564, checking inheritance; variant info: 0|1, 0.14285714285714285, 140
# {'sibling': 77092563, 'mother': 77092565}
# 32038948_T_TC not found in gt_hc of 77092565 - the mother of 77092564
# 32038948_T_TC not found in gt_dv of 77092565 - the mother of 77092564
# no 32038948_T_TC found in mother
# []
# droping this variant, probably artefact
# low qual 32038949_T_G in 77092564, checking inheritance; variant info: 0|1, 0.14285714285714285, 140
# {'sibling': 77092563, 'mother': 77092565}
# 32038949_T_G not found in gt_hc of 77092565 - the mother of 77092564
# 32038949_T_G not found in gt_dv of 77092565 - the mother of 77092564
# no 32038949_T_G found in mother
# []
# droping this variant, probably artefact
# low qual 32038955_A_T in 77092564, checking inheritance; variant info: 0|1, 0.14814814814814814, 135
# {'sibling': 77092563, 'mother': 77092565}
# 32038955_A_T not found in gt_hc of 77092565 - the mother of 77092564
# 32038955_A_T not found in gt_dv of 77092565 - the mother of 77092564
# no 32038955_A_T found in mother
# []
# droping this variant, probably artefact
# low qual 32038962_A_ATCC in 77092564, checking inheritance; variant info: 0|1, 0.08620689655172414, 58
# {'sibling': 77092563, 'mother': 77092565}
# 32038962_A_ATCC not found in gt_hc of 77092565 - the mother of 77092564
# 32038962_A_ATCC not found in gt_dv of 77092565 - the mother of 77092564
# no 32038962_A_ATCC found in mother
# []
# droping this variant, probably artefact
# low qual 32038983_TG_T in 77092564, checking inheritance; variant info: 0|1, 0.1111111111111111, 36
# {'sibling': 77092563, 'mother': 77092565}
# 32038983_TG_T not found in gt_hc of 77092565 - the mother of 77092564
# 32038983_TG_T not found in gt_dv of 77092565 - the mother of 77092564
# no 32038983_TG_T found in mother
# []
# droping this variant, probably artefact
# low qual 32038997_TGG_T in 77092564, checking inheritance; variant info: 0|1, 0.1282051282051282, 39
# {'sibling': 77092563, 'mother': 77092565}
# 32038997_TGG_T not found in gt_hc of 77092565 - the mother of 77092564
# 32038997_TGG_T not found in gt_dv of 77092565 - the mother of 77092564
# no 32038997_TGG_T found in mother
# []
# droping this variant, probably artefact
# low qual 32039001_G_C in 77092564, checking inheritance; variant info: 0|1, 0.15151515151515152, 33
# {'sibling': 77092563, 'mother': 77092565}
# 32039001_G_C not found in gt_hc of 77092565 - the mother of 77092564
# 32039001_G_C not found in gt_dv of 77092565 - the mother of 77092564
# no 32039001_G_C found in mother
# []
# droping this variant, probably artefact
# low qual 32039002_G_A in 77092564, checking inheritance; variant info: 0|1, 0.15151515151515152, 33
# {'sibling': 77092563, 'mother': 77092565}
# 32039002_G_A not found in gt_hc of 77092565 - the mother of 77092564
# 32039002_G_A not found in gt_dv of 77092565 - the mother of 77092564
# no 32039002_G_A found in mother
# []
# droping this variant, probably artefact
# low qual 32039020_G_A in 77092564, checking inheritance; variant info: 0|1, 0.3448275862068966, 29
# {'sibling': 77092563, 'mother': 77092565}
# 32039020_G_A not found in gt_hc of 77092565 - the mother of 77092564
# 32039020_G_A not found in gt_dv of 77092565 - the mother of 77092564
# no 32039020_G_A found in mother
# []
# droping this variant, probably artefact
# low qual 32039027_C_A in 77092564, checking inheritance; variant info: 0|1, 0.3448275862068966, 29
# {'sibling': 77092563, 'mother': 77092565}
# 32039027_C_A not found in gt_hc of 77092565 - the mother of 77092564
# 32039027_C_A not found in gt_dv of 77092565 - the mother of 77092564
# no 32039027_C_A found in mother
# []
# droping this variant, probably artefact
# low qual 32039046_A_G in 77092564, checking inheritance; variant info: 0|1, 0.5185185185185185, 27
# {'sibling': 77092563, 'mother': 77092565}
# 32039046_A_G not found in gt_hc of 77092565 - the mother of 77092564
# 32039046_A_G not found in gt_dv of 77092565 - the mother of 77092564
# no 32039046_A_G found in mother
# []
# droping this variant, probably artefact
# low qual 32039050_G_T in 77092564, checking inheritance; variant info: 0|1, 0.6153846153846154, 26
# {'sibling': 77092563, 'mother': 77092565}
# 32039050_G_T not found in gt_hc of 77092565 - the mother of 77092564
# 32039050_G_T not found in gt_dv of 77092565 - the mother of 77092564
# no 32039050_G_T found in mother
# []
# droping this variant, probably artefact
# low qual 32039055_C_G in 77092564, checking inheritance; variant info: 0|1, 0.68, 25
# {'sibling': 77092563, 'mother': 77092565}
# 32039055_C_G not found in gt_hc of 77092565 - the mother of 77092564
# 32039055_C_G not found in gt_dv of 77092565 - the mother of 77092564
# no 32039055_C_G found in mother
# []
# droping this variant, probably artefact
# low qual 32039056_A_G in 77092564, checking inheritance; variant info: 0|1, 0.7083333333333334, 24
# {'sibling': 77092563, 'mother': 77092565}
# 32039056_A_G not found in gt_hc of 77092565 - the mother of 77092564
# 32039056_A_G not found in gt_dv of 77092565 - the mother of 77092564
# no 32039056_A_G found in mother
# []
# droping this variant, probably artefact
# low qual 32038855_T_TTG in 77092571, checking inheritance; variant info: 1|0, 0.14919144496609285, 1917
# {'mother': 77092570}
# 32038855_T_TTG not found in gt_hc of 77092570 - the mother of 77092571
# 32038855_T_TTG not found in gt_dv of 77092570 - the mother of 77092571
# no 32038855_T_TTG found in mother
# []
# droping this variant, probably artefact
# for 77092571 comparing 32038855_T_TTTG with HC - 1|0 and DV - 1/1
# dv right with 1/1, VAF - 0.8686131386861314, DP-137
# low qual 32038855_T_TTG in 77092572, checking inheritance; variant info: 1|0, 0.15139442231075698, 2008
# {'mother': 77092573}
# 32038855_T_TTG not found in gt_hc of 77092573 - the mother of 77092572
# 32038855_T_TTG not found in gt_dv of 77092573 - the mother of 77092572
# no 32038855_T_TTG found in mother
# []
# droping this variant, probably artefact
# for 77092572 comparing 32038855_T_TTTG with HC - 1|0 and DV - 1/1
# hc right with 1|0, VAF - 0.848605577689243, DP-2008
# low qual 32038855_T_TTG in 77092576, checking inheritance; variant info: 1|0, 0.14457202505219208, 1926
# {'mother': 77092574, 'sibling': 77092575}
# 32038855_T_TTG not found in gt_hc of 77092574 - the mother of 77092576
# 32038855_T_TTG not found in gt_dv of 77092574 - the mother of 77092576
# no 32038855_T_TTG found in mother
# []
# droping this variant, probably artefact
# for 77092576 comparing 32038855_T_TTTG with HC - 1|0 and DV - 1/1
# both wrong, checking inheritance; variant info: 1|0, 0.855427974947808, 1926 AND 1/1, 0.8248175182481752, 137
# {'mother': 77092574, 'sibling': 77092575}
# found 32038855_T_TTTG in 77092574 HC data - ['0|1', 0.4636604774535809, 1885]
# checking relative variant with ['0|1', 0.4636604774535809, 1885] AND ['0/1', 0.3310810810810811, 148]
# found 32038855_T_TTTG in mother with genotype 0|1
# ['0|1']
# saving this variant even with bad QUAL
# for 77092576 comparing 32041186_C_T with HC - 1|1 and DV - 0/1
# hc right with 1|1, VAF - 0.9994941831057157, DP-1977
# low qual 32038855_T_TTG in 77092577, checking inheritance; variant info: 1|0, 0.12160694896851248, 1853
# {'father': 77092579, 'sibling': 77092580, 'mother': 77092578}
# 32038855_T_TTG not found in gt_hc of 77092579 - the father of 77092577
# 32038855_T_TTG not found in gt_dv of 77092579 - the father of 77092577
# no 32038855_T_TTG found in father
# 32038855_T_TTG not found in gt_hc of 77092578 - the mother of 77092577
# 32038855_T_TTG not found in gt_dv of 77092578 - the mother of 77092577
# no 32038855_T_TTG found in mother
# []
# droping this variant, probably artefact
# for 77092577 comparing 32038855_T_TTTG with HC - 1|0 and DV - 1/1
# dv right with 1/1, VAF - 0.8561151079136691, DP-139
# for 77092583 comparing 32038985_G_C with HC - 0|1 and DV - 1/1
# hc right with 0|1, VAF - 0.54411161263849, DP-2437
# low qual 32038855_T_TTG in 77092584, checking inheritance; variant info: 1|0, 0.1755666538609297, 2637
# {'mother': 77092583}
# 32038855_T_TTG not found in gt_hc of 77092583 - the mother of 77092584
# 32038855_T_TTG not found in gt_dv of 77092583 - the mother of 77092584
# no 32038855_T_TTG found in mother
# []
# droping this variant, probably artefact
# for 77092584 comparing 32038855_T_TTTG with HC - 1|0 and DV - 1/1
# hc right with 1|0, VAF - 0.8244333461390703, DP-2637
# low qual 32038855_T_TTG in 77092593, checking inheritance; variant info: 1|0, 0.1286549707602339, 172
# {'mother': 77092591, 'father': 77092592, 'sibling': 77092594}
# 32038855_T_TTG not found in gt_hc of 77092591 - the mother of 77092593
# 32038855_T_TTG not found in gt_dv of 77092591 - the mother of 77092593
# no 32038855_T_TTG found in mother
# 32038855_T_TTG not found in gt_hc of 77092592 - the father of 77092593
# 32038855_T_TTG not found in gt_dv of 77092592 - the father of 77092593
# no 32038855_T_TTG found in father
# []
# droping this variant, probably artefact
# for 77092593 comparing 32038855_T_TTTG with HC - 1|0 and DV - 1/1
# both wrong, checking inheritance; variant info: 1|0, 0.8713450292397661, 172 AND 1/1, 0.634453781512605, 238
# {'mother': 77092591, 'father': 77092592, 'sibling': 77092594}
# found 32038855_T_TTTG in 77092591 HC data - ['0|1', 0.3825136612021858, 183]
# checking relative variant with ['0|1', 0.3825136612021858, 183] AND ['0/1', 0.26557377049180325, 305]
# found 32038855_T_TTTG in mother with genotype 0|1
# found 32038855_T_TTTG in 77092592 HC data - ['1|0', 0.45850914205344584, 2844]
# checking relative variant with ['1|0', 0.45850914205344584, 2844] AND ['0/1', 0.33881578947368424, 304]
# found 32038855_T_TTTG in father with genotype 1|0
# ['0|1', '1|0']
# saving this variant even with bad QUAL
# for 77092594 comparing 32038949_T_G with HC - 1|1 and DV - 1/0
# hc right with 1|1, VAF - 1.0, DP-105
# low qual 32038949_T_C in 77092594, checking inheritance; variant info: 1/0, 0.145985401459854, 141
# {'mother': 77092591, 'father': 77092592, 'sibling': 77092595}
# 32038949_T_C not found in gt_hc of 77092591 - the mother of 77092594
# 32038949_T_C not found in gt_dv of 77092591 - the mother of 77092594
# no 32038949_T_C found in mother
# 32038949_T_C not found in gt_hc of 77092592 - the father of 77092594
# 32038949_T_C not found in gt_dv of 77092592 - the father of 77092594
# no 32038949_T_C found in father
# []
# droping this variant, probably artefact
# low qual 32038855_T_TTG in 77092595, checking inheritance; variant info: 1|0, 0.19863013698630136, 149
# {'mother': 77092591, 'father': 77092592, 'sibling': 77092594}
# 32038855_T_TTG not found in gt_hc of 77092591 - the mother of 77092595
# 32038855_T_TTG not found in gt_dv of 77092591 - the mother of 77092595
# no 32038855_T_TTG found in mother
# 32038855_T_TTG not found in gt_hc of 77092592 - the father of 77092595
# 32038855_T_TTG not found in gt_dv of 77092592 - the father of 77092595
# no 32038855_T_TTG found in father
# []
# droping this variant, probably artefact
# for 77092595 comparing 32038855_T_TTTG with HC - 1|0 and DV - 1/1
# hc right with 1|0, VAF - 0.8013698630136986, DP-149
# for 77092595 comparing 32038949_T_G with HC - 1|1 and DV - 1/0
# hc right with 1|1, VAF - 1.0, DP-133
# low qual 32038949_T_C in 77092595, checking inheritance; variant info: 1/0, 0.16216216216216217, 149
# {'mother': 77092591, 'father': 77092592, 'sibling': 77092594}
# 32038949_T_C not found in gt_hc of 77092591 - the mother of 77092595
# 32038949_T_C not found in gt_dv of 77092591 - the mother of 77092595
# no 32038949_T_C found in mother
# 32038949_T_C not found in gt_hc of 77092592 - the father of 77092595
# 32038949_T_C not found in gt_dv of 77092592 - the father of 77092595
# no 32038949_T_C found in father
# []
# droping this variant, probably artefact
# low qual 32038855_T_TTG in 77092609, checking inheritance; variant info: 1|0, 0.15171650055370986, 1862
# {'mother': 77092608, 'father': 77092607}
# 32038855_T_TTG not found in gt_hc of 77092608 - the mother of 77092609
# 32038855_T_TTG not found in gt_dv of 77092608 - the mother of 77092609
# no 32038855_T_TTG found in mother
# 32038855_T_TTG not found in gt_hc of 77092607 - the father of 77092609
# 32038855_T_TTG not found in gt_dv of 77092607 - the father of 77092609
# no 32038855_T_TTG found in father
# []
# droping this variant, probably artefact
# for 77092609 comparing 32038855_T_TTTG with HC - 1|0 and DV - 1/1
# hc right with 1|0, VAF - 0.8482834994462901, DP-1862
# for 77092617 comparing 32038855_T_TTTG with HC - 1|0 and DV - 1/1
# hc right with 1|0, VAF - 0.8250123578843302, DP-2047
# low qual 32038855_T_TTG in 77092617, checking inheritance; variant info: 1|0, 0.1749876421156698, 2047
# {'mother': 77092618}
# 32038855_T_TTG not found in gt_hc of 77092618 - the mother of 77092617
# 32038855_T_TTG not found in gt_dv of 77092618 - the mother of 77092617
# no 32038855_T_TTG found in mother
# []
# droping this variant, probably artefact
# low qual 32039007_A_AAG in 77092627, checking inheritance; variant info: 0|1, 0.44, 25
# {'child': 77092646}
# found 32039007_A_AAG in 77092646 HC data - ['1|1', 1.0, 40]
# checking relative variant with ['1|1', 1.0, 40] AND ['1/1', 0.978021978021978, 91]
# found 32039007_A_AAG in child with genotype 1|1
# ['1|1']
# saving this variant even with bad QUAL
# low qual 32039015_G_T in 77092627, checking inheritance; variant info: 0|1, 0.48148148148148145, 27
# {'child': 77092646}
# found 32039015_G_T in 77092646 HC data - ['1|1', 1.0, 35]
# checking relative variant with ['1|1', 1.0, 35] AND ['1/1', 0.967948717948718, 156]
# found 32039015_G_T in child with genotype 1|1
# ['1|1']
# saving this variant even with bad QUAL
# low qual 32039020_G_A in 77092627, checking inheritance; variant info: 0|1, 0.48148148148148145, 27
# {'child': 77092646}
# found 32039020_G_A in 77092646 HC data - ['1|1', 1.0, 34]
# checking relative variant with ['1|1', 1.0, 34] AND ['1/1', 0.9871794871794872, 156]
# found 32039020_G_A in child with genotype 1|1
# ['1|1']
# saving this variant even with bad QUAL
# low qual 32039006_G_A in 77092633, checking inheritance; variant info: 0|1, 0.14705882352941177, 68
# {'child': 77092644}
# 32039006_G_A not found in gt_hc of 77092644 - the child of 77092633
# 32039006_G_A not found in gt_dv of 77092644 - the child of 77092633
# no 32039006_G_A found in child
# []
# droping this variant, probably artefact
# low qual 32039027_C_A in 77092635, checking inheritance; variant info: 0|1, 0.8571428571428571, 35
# {'spouse': 77092636, 'child': 77092641}
# found 32039027_C_A in 77092641 HC data - ['0|1', 0.6140350877192983, 57]
# 32039027_C_A found only in HC data of child
# found a heterozygote 32039027_C_A in child with VAF 0.6140350877192983
# ['0|1']
# saving this variant even with bad QUAL
# low qual 32039046_A_G in 77092635, checking inheritance; variant info: 0|1, 0.8717948717948718, 39
# {'spouse': 77092636, 'child': 77092641}
# found 32039046_A_G in 77092641 HC data - ['0|1', 0.603448275862069, 58]
# 32039046_A_G found only in HC data of child
# found a heterozygote 32039046_A_G in child with VAF 0.603448275862069
# ['0|1']
# saving this variant even with bad QUAL
# for 77092640 comparing 32038855_T_TTTG with HC - 1|0 and DV - 1/1
# hc right with 1|0, VAF - 0.734375, DP-68
# for 77092640 comparing 32038949_T_G with HC - 1|1 and DV - 1/0
# dv right with 1/0, VAF - 0.8145695364238411, DP-155
# low qual 32039001_G_C in 77092640, checking inheritance; variant info: 1|1, 1.0, 27
# {'mother': 77092629, 'father': 77092630}
# found 32039001_G_C in 77092629 HC data - ['0|1', 0.40384615384615385, 104]
# 32039001_G_C found only in HC data of mother
# found a heterozygote 32039001_G_C in mother with VAF 0.40384615384615385
# 32039001_G_C not found in gt_hc of 77092630 - the father of 77092640
# 32039001_G_C not found in gt_dv of 77092630 - the father of 77092640
# no 32039001_G_C found in father
# ['0|1']
# saving this variant even with bad QUAL
# low qual 32038949_T_C in 77092640, checking inheritance; variant info: 1/0, 0.18543046357615894, 155
# {'mother': 77092629, 'father': 77092630}
# 32038949_T_C not found in gt_hc of 77092629 - the mother of 77092640
# 32038949_T_C not found in gt_dv of 77092629 - the mother of 77092640
# no 32038949_T_C found in mother
# 32038949_T_C not found in gt_hc of 77092630 - the father of 77092640
# 32038949_T_C not found in gt_dv of 77092630 - the father of 77092640
# no 32038949_T_C found in father
# []
# droping this variant, probably artefact
# for 77092646 comparing 32038855_T_TTTG with HC - 1|0 and DV - 1/1
# hc right with 1|0, VAF - 0.7171717171717171, DP-99
# low qual 32038855_T_TTG in 77092662, checking inheritance; variant info: 1|0, 0.14657210401891252, 2115
# {}
# []
# droping this variant, probably artefact
# for 77092662 comparing 32038855_T_TTTG with HC - 1|0 and DV - 1/1
# dv right with 1/1, VAF - 0.8904109589041096, DP-146
# low qual 32038895_A_G in 77092666, checking inheritance; variant info: 0|1, 0.2916666666666667, 24
# {}
# []
# droping this variant, probably artefact
# low qual 32038903_A_G in 77092666, checking inheritance; variant info: 0|1, 0.4117647058823529, 17
# {}
# []
# droping this variant, probably artefact
# low qual 32038911_A_G in 77092666, checking inheritance; variant info: 0|1, 0.25, 16
# {}
# []
# droping this variant, probably artefact
# low qual 32038948_T_TC in 77092666, checking inheritance; variant info: 0|1, 0.14285714285714285, 14
# {}
# []
# droping this variant, probably artefact
# low qual 32038949_T_G in 77092666, checking inheritance; variant info: 0|1, 0.14285714285714285, 14
# {}
# []
# droping this variant, probably artefact
# low qual 32038955_A_T in 77092666, checking inheritance; variant info: 0|1, 0.125, 16
# {}
# []
# droping this variant, probably artefact
# low qual 32038962_A_ATCC in 77092666, checking inheritance; variant info: 0|1, 0.26666666666666666, 15
# {}
# []
# droping this variant, probably artefact
# low qual 32038971_C_A in 77092666, checking inheritance; variant info: 0|1, 0.21052631578947367, 19
# {}
# []
# droping this variant, probably artefact
# low qual 32038983_TG_T in 77092666, checking inheritance; variant info: 0|1, 0.38095238095238093, 21
# {}
# []
# droping this variant, probably artefact
# low qual 32038997_TGG_T in 77092666, checking inheritance; variant info: 0|1, 0.4117647058823529, 17
# {}
# []
# droping this variant, probably artefact
# low qual 32039001_G_C in 77092666, checking inheritance; variant info: 0|1, 0.4117647058823529, 17
# {}
# []
# droping this variant, probably artefact
# low qual 32039002_G_A in 77092666, checking inheritance; variant info: 0|1, 0.4117647058823529, 17
# {}
# []
# droping this variant, probably artefact
# low qual 32039007_A_AAG in 77092666, checking inheritance; variant info: 0|1, 0.5333333333333333, 15
# {}
# []
# droping this variant, probably artefact
# low qual 32039015_G_T in 77092666, checking inheritance; variant info: 0|1, 0.5882352941176471, 17
# {}
# []
# droping this variant, probably artefact
# low qual 32039020_G_A in 77092666, checking inheritance; variant info: 0|1, 0.65, 20
# {}
# []
# droping this variant, probably artefact
# low qual 32039027_C_A in 77092666, checking inheritance; variant info: 0|1, 0.7368421052631579, 19
# {}
# []
# droping this variant, probably artefact
# low qual 32039046_A_G in 77092666, checking inheritance; variant info: 0|1, 0.8148148148148148, 27
# {}
# []
# droping this variant, probably artefact
# low qual 32038855_T_TTG in 77092668, checking inheritance; variant info: 1|0, 0.1458625525946704, 2144
# {}
# []
# droping this variant, probably artefact
# for 77092668 comparing 32038855_T_TTTG with HC - 1|0 and DV - 1/1
# dv right with 1/1, VAF - 0.8714285714285714, DP-140
# for 77092669 comparing 32038855_T_TTTG with HC - 1|0 and DV - 1/1
# hc right with 1|0, VAF - 0.8465346534653465, DP-2020
# low qual 32038855_T_TTG in 77092669, checking inheritance; variant info: 1|0, 0.15346534653465346, 2020
# {}
# []
# droping this variant, probably artefact
# low qual 32038962_A_ATCC in 77092671, checking inheritance; variant info: 0|1, 0.11678832116788321, 137
# {}
# []
# droping this variant, probably artefact
# low qual 32038971_C_A in 77092671, checking inheritance; variant info: 0|1, 0.11594202898550725, 138
# {}
# []
# droping this variant, probably artefact
# for 77092672 comparing 32041186_C_T with HC - 1|0 and DV - 1/1
# hc right with 1|0, VAF - 0.6990241397021058, DP-1947
# low qual 32038855_T_TTG in 77092673, checking inheritance; variant info: 1|0, 0.13562091503267973, 613
# {}
# []
# droping this variant, probably artefact
# for 77092673 comparing 32038855_T_TTTG with HC - 1|0 and DV - 1/1
# dv right with 1/1, VAF - 0.8840579710144928, DP-138
# low qual 32038539_C_CTTG in 77092674, checking inheritance; variant info: 1|0, 0.1694915254237288, 59
# {}
# []
# droping this variant, probably artefact
# low qual 32038997_TGG_T in 77092674, checking inheritance; variant info: 0|1, 0.15873015873015872, 63
# {}
# []
# droping this variant, probably artefact
# low qual 32039001_G_C in 77092674, checking inheritance; variant info: 0|1, 0.15517241379310345, 58
# {}
# []
# droping this variant, probably artefact
# low qual 32039002_G_A in 77092674, checking inheritance; variant info: 0|1, 0.15789473684210525, 57
# {}
# []
# droping this variant, probably artefact
# low qual 32040112_G_GCA in 77092674, checking inheritance; variant info: 0|1, 0.12643678160919541, 174
# {}
# []
# droping this variant, probably artefact
# for 77092704 comparing 32038855_T_TTTG with HC - 1|0 and DV - 1/1
# dv right with 1/1, VAF - 0.9166666666666666, DP-228
# low qual 32038855_T_TTG in 77092704, checking inheritance; variant info: 1|0, 0.13663616282739036, 3176
# {'father': 77092703, 'sibling': 77092705}
# 32038855_T_TTG not found in gt_hc of 77092703 - the father of 77092704
# 32038855_T_TTG not found in gt_dv of 77092703 - the father of 77092704
# no 32038855_T_TTG found in father
# []
# droping this variant, probably artefact
# for 77092705 comparing 32038855_T_TTTG with HC - 1|0 and DV - 1/1
# hc right with 1|0, VAF - 0.8390659514042285, DP-3169
# low qual 32038855_T_TTG in 77092705, checking inheritance; variant info: 1|0, 0.16093404859577154, 3169
# {'father': 77092703, 'sibling': 77092704}
# 32038855_T_TTG not found in gt_hc of 77092703 - the father of 77092705
# ...
# saving this variant even with bad QUAL
# low qual 32039027_C_A in 77095338, checking inheritance; variant info: 1|0, 0.14705882352941177, 34
# {'sibling': 77095337, 'father': 77095339, 'mother': 77095341}
# found 32039027_C_A in 77095339 HC data - ['0|1', 0.376, 125]
# 32039027_C_A found only in HC data of father
# found a heterozygote 32039027_C_A in father with VAF 0.376
# 32039027_C_A not found in gt_hc of 77095341 - the mother of 77095338
# 32039027_C_A not found in gt_dv of 77095341 - the mother of 77095338
# no 32039027_C_A found in mother
# ['0|1']
# saving this variant even with bad QUAL
# low qual 32039056_A_G in 77095338, checking inheritance; variant info: 1|0, 0.17647058823529413, 136
# {'sibling': 77095337, 'father': 77095339, 'mother': 77095341}
# found 32039056_A_G in 77095339 HC data - ['0|1', 0.397212543554007, 287]
# 32039056_A_G found only in HC data of father
# found a heterozygote 32039056_A_G in father with VAF 0.397212543554007
# 32039056_A_G not found in gt_hc of 77095341 - the mother of 77095338
# 32039056_A_G not found in gt_dv of 77095341 - the mother of 77095338
# no 32039056_A_G found in mother
# ['0|1']
# saving this variant even with bad QUAL
# low qual 32038903_A_G in 77095339, checking inheritance; variant info: 0|1, 0.39285714285714285, 28
# {'child': 77095337, 'spouse': 77095341}
# 32038903_A_G not found in gt_hc of 77095337 - the child of 77095339
# 32038903_A_G not found in gt_dv of 77095337 - the child of 77095339
# no 32038903_A_G found in child
# []
# droping this variant, probably artefact
# low qual 32038938_T_G in 77095339, checking inheritance; variant info: 0|1, 0.5217391304347826, 23
# {'child': 77095337, 'spouse': 77095341}
# 32038938_T_G not found in gt_hc of 77095337 - the child of 77095339
# 32038938_T_G not found in gt_dv of 77095337 - the child of 77095339
# no 32038938_T_G found in child
# []
# droping this variant, probably artefact
# low qual 32038948_T_TC in 77095339, checking inheritance; variant info: 0|1, 0.4074074074074074, 27
# {'child': 77095337, 'spouse': 77095341}
# 32038948_T_TC not found in gt_hc of 77095337 - the child of 77095339
# 32038948_T_TC not found in gt_dv of 77095337 - the child of 77095339
# no 32038948_T_TC found in child
# []
# droping this variant, probably artefact
# low qual 32038962_A_ATCC in 77095339, checking inheritance; variant info: 0|1, 0.36, 25
# {'child': 77095337, 'spouse': 77095341}
# 32038962_A_ATCC not found in gt_hc of 77095337 - the child of 77095339
# 32038962_A_ATCC not found in gt_dv of 77095337 - the child of 77095339
# no 32038962_A_ATCC found in child
# []
# droping this variant, probably artefact
# low qual 32038971_C_A in 77095339, checking inheritance; variant info: 0|1, 0.30434782608695654, 23
# {'child': 77095337, 'spouse': 77095341}
# 32038971_C_A not found in gt_hc of 77095337 - the child of 77095339
# 32038971_C_A not found in gt_dv of 77095337 - the child of 77095339
# no 32038971_C_A found in child
# []
# droping this variant, probably artefact
# low qual 32038983_TG_T in 77095339, checking inheritance; variant info: 0|1, 0.3684210526315789, 19
# {'child': 77095337, 'spouse': 77095341}
# 32038983_TG_T not found in gt_hc of 77095337 - the child of 77095339
# 32038983_TG_T not found in gt_dv of 77095337 - the child of 77095339
# no 32038983_TG_T found in child
# []
# droping this variant, probably artefact
# low qual 32038983_TG_T in 77095340, checking inheritance; variant info: 0|1, 0.6296296296296297, 27
# {'child': 77095335, 'spouse': 77095334}
# found 32038983_TG_T in 77095335 HC data - ['1|1', 1.0, 16]
# 32038983_TG_T found only in HC data of child
# found a lowqual homozygote 32038983_TG_T in child with right VAF 1.0, but low DP - 16
# found only low qual 32038983_TG_T in child with 1.0 and 16, probably an artefact
# ['1|1']
# saving this variant even with bad QUAL
# low qual 32038997_TGG_T in 77095340, checking inheritance; variant info: 0|1, 0.47058823529411764, 17
# {'child': 77095335, 'spouse': 77095334}
# found 32038997_TGG_T in 77095335 HC data - ['1|1', 1.0, 8]
# 32038997_TGG_T found only in HC data of child
# found a lowqual homozygote 32038997_TGG_T in child with right VAF 1.0, but low DP - 8
# found only low qual 32038997_TGG_T in child with 1.0 and 8, probably an artefact
# ['1|1']
# saving this variant even with bad QUAL
# low qual 32039001_G_C in 77095340, checking inheritance; variant info: 0|1, 0.5, 14
# {'child': 77095335, 'spouse': 77095334}
# found 32039001_G_C in 77095335 HC data - ['1|1', 1.0, 4]
# 32039001_G_C found only in HC data of child
# found a lowqual homozygote 32039001_G_C in child with right VAF 1.0, but low DP - 4
# found only low qual 32039001_G_C in child with 1.0 and 4, probably an artefact
# ['1|1']
# saving this variant even with bad QUAL
# low qual 32039002_G_A in 77095340, checking inheritance; variant info: 0|1, 0.5, 14
# {'child': 77095335, 'spouse': 77095334}
# found 32039002_G_A in 77095335 HC data - ['1|1', 1.0, 5]
# checking relative variant with ['1|1', 1.0, 5] AND ['1/1', 0.9629629629629629, 27]
# found 32039002_G_A in child with genotype 1|1
# ['1|1']
# saving this variant even with bad QUAL
# low qual 32039007_A_AAG in 77095340, checking inheritance; variant info: 0|1, 0.5, 12
# {'child': 77095335, 'spouse': 77095334}
# found 32039007_A_AAG in 77095335 HC data - ['1|1', 1.0, 4]
# 32039007_A_AAG found only in HC data of child
# found a lowqual homozygote 32039007_A_AAG in child with right VAF 1.0, but low DP - 4
# found only low qual 32039007_A_AAG in child with 1.0 and 4, probably an artefact
# ['1|1']
# saving this variant even with bad QUAL
# low qual 32039015_G_T in 77095340, checking inheritance; variant info: 0|1, 0.45454545454545453, 11
# {'child': 77095335, 'spouse': 77095334}
# found 32039015_G_T in 77095335 HC data - ['1|1', 1.0, 5]
# checking relative variant with ['1|1', 1.0, 5] AND ['1/1', 0.9444444444444444, 72]
# found 32039015_G_T in child with genotype 1|1
# ['1|1']
# saving this variant even with bad QUAL
# low qual 32039020_G_A in 77095340, checking inheritance; variant info: 0|1, 0.45454545454545453, 11
# {'child': 77095335, 'spouse': 77095334}
# found 32039020_G_A in 77095335 HC data - ['1|1', 1.0, 7]
# checking relative variant with ['1|1', 1.0, 7] AND ['1/1', 0.9863013698630136, 73]
# found 32039020_G_A in child with genotype 1|1
# ['1|1']
# saving this variant even with bad QUAL
# low qual 32039027_C_A in 77095340, checking inheritance; variant info: 0|1, 0.6666666666666666, 18
# {'child': 77095335, 'spouse': 77095334}
# found 32039027_C_A in 77095335 HC data - ['1|1', 1.0, 7]
# checking relative variant with ['1|1', 1.0, 7] AND ['1/1', 0.9130434782608695, 92]
# found 32039027_C_A in child with genotype 1|1
# ['1|1']
# saving this variant even with bad QUAL
# low qual 32038962_A_ATCC in 77095342, checking inheritance; variant info: 0|1, 0.17857142857142858, 28
# {'spouse': 77095343, 'child': 77095344}
# found 32038962_A_ATCC in 77095344 HC data - ['1|0', 0.35, 40]
# 32038962_A_ATCC found only in HC data of child
# found a heterozygote 32038962_A_ATCC in child with VAF 0.35
# ['1|0']
# saving this variant even with bad QUAL
# low qual 32038983_TG_T in 77095342, checking inheritance; variant info: 0|1, 0.10714285714285714, 28
# {'spouse': 77095343, 'child': 77095344}
# 32038983_TG_T not found in gt_hc of 77095344 - the child of 77095342
# 32038983_TG_T not found in gt_dv of 77095344 - the child of 77095342
# no 32038983_TG_T found in child
# []
# droping this variant, probably artefact
# low qual 32038997_TGG_T in 77095342, checking inheritance; variant info: 0|1, 0.1282051282051282, 39
# {'spouse': 77095343, 'child': 77095344}
# 32038997_TGG_T not found in gt_hc of 77095344 - the child of 77095342
# 32038997_TGG_T not found in gt_dv of 77095344 - the child of 77095342
# no 32038997_TGG_T found in child
# []
# droping this variant, probably artefact
# low qual 32039001_G_C in 77095342, checking inheritance; variant info: 0|1, 0.15384615384615385, 39
# {'spouse': 77095343, 'child': 77095344}
# 32039001_G_C not found in gt_hc of 77095344 - the child of 77095342
# 32039001_G_C not found in gt_dv of 77095344 - the child of 77095342
# no 32039001_G_C found in child
# []
# droping this variant, probably artefact
# low qual 32039002_G_A in 77095342, checking inheritance; variant info: 0|1, 0.15384615384615385, 39
# {'spouse': 77095343, 'child': 77095344}
# 32039002_G_A not found in gt_hc of 77095344 - the child of 77095342
# 32039002_G_A not found in gt_dv of 77095344 - the child of 77095342
# no 32039002_G_A found in child
# []
# droping this variant, probably artefact
# low qual 32038971_C_A in 77095344, checking inheritance; variant info: 1|0, 0.36363636363636365, 22
# {'father': 77095343, 'mother': 77095342}
# 32038971_C_A not found in gt_hc of 77095343 - the father of 77095344
# 32038971_C_A not found in gt_dv of 77095343 - the father of 77095344
# no 32038971_C_A found in father
# 32038971_C_A not found in gt_hc of 77095342 - the mother of 77095344
# 32038971_C_A not found in gt_dv of 77095342 - the mother of 77095344
# no 32038971_C_A found in mother
# []
# droping this variant, probably artefact
# low qual 32039015_G_T in 77095344, checking inheritance; variant info: 1|0, 0.15384615384615385, 13
# {'father': 77095343, 'mother': 77095342}
# 32039015_G_T not found in gt_hc of 77095343 - the father of 77095344
# 32039015_G_T not found in gt_dv of 77095343 - the father of 77095344
# no 32039015_G_T found in father
# found 32039015_G_T in 77095342 HC data - ['0|1', 0.38095238095238093, 84]
# 32039015_G_T found only in HC data of mother
# found a heterozygote 32039015_G_T in mother with VAF 0.38095238095238093
# ['0|1']
# saving this variant even with bad QUAL
# low qual 32039020_G_A in 77095344, checking inheritance; variant info: 1|0, 0.21428571428571427, 14
# {'father': 77095343, 'mother': 77095342}
# 32039020_G_A not found in gt_hc of 77095343 - the father of 77095344
# 32039020_G_A not found in gt_dv of 77095343 - the father of 77095344
# no 32039020_G_A found in father
# found 32039020_G_A in 77095342 HC data - ['0|1', 0.3977272727272727, 88]
# 32039020_G_A found only in HC data of mother
# found a heterozygote 32039020_G_A in mother with VAF 0.3977272727272727
# ['0|1']
# saving this variant even with bad QUAL
# low qual 32039027_C_A in 77095344, checking inheritance; variant info: 1|0, 0.21428571428571427, 14
# {'father': 77095343, 'mother': 77095342}
# 32039027_C_A not found in gt_hc of 77095343 - the father of 77095344
# 32039027_C_A not found in gt_dv of 77095343 - the father of 77095344
# no 32039027_C_A found in father
# found 32039027_C_A in 77095342 HC data - ['0|1', 0.4017094017094017, 117]
# 32039027_C_A found only in HC data of mother
# found a heterozygote 32039027_C_A in mother with VAF 0.4017094017094017
# ['0|1']
# saving this variant even with bad QUAL
# low qual 32039046_A_G in 77095344, checking inheritance; variant info: 1|0, 0.4117647058823529, 17
# {'father': 77095343, 'mother': 77095342}
# 32039046_A_G not found in gt_hc of 77095343 - the father of 77095344
# 32039046_A_G not found in gt_dv of 77095343 - the father of 77095344
# no 32039046_A_G found in father
# found 32039046_A_G in 77095342 HC data - ['0|1', 0.47282608695652173, 184]
# 32039046_A_G found only in HC data of mother
# found a heterozygote 32039046_A_G in mother with VAF 0.47282608695652173
# ['0|1']
# saving this variant even with bad QUAL
# for 77095346 comparing 32038844_A_C with HC - 1|0 and DV - 1/1
# dv right with 1/1, VAF - 0.8739130434782608, DP-230
# for 77095346 comparing 32038855_T_TTTG with HC - 1|0 and DV - 1/1
# both wrong, checking inheritance; variant info: 1|0, 0.3, 10 AND 1/1, 0.5228426395939086, 197
# {'sibling': 77095345}
# []
# droping this variant, probably artefact
# for 77095346 comparing 32038857_A_T with HC - 1|0 and DV - 1/1
# dv right with 1/1, VAF - 0.9657534246575342, DP-146
# for 77095346 comparing 32038949_T_G with HC - 1|1 and DV - 1/0
# hc right with 1|1, VAF - 1.0, DP-182
# low qual 32038949_T_C in 77095346, checking inheritance; variant info: 1/0, 0.1509433962264151, 54
# {'sibling': 77095345}
# []
# droping this variant, probably artefact
# low qual 32038948_T_TC in 77095350, checking inheritance; variant info: 0|1, 0.15675675675675677, 185
# {'spouse': 77095347, 'child': 77095354}
# 32038948_T_TC not found in gt_hc of 77095354 - the child of 77095350
# 32038948_T_TC not found in gt_dv of 77095354 - the child of 77095350
# no 32038948_T_TC found in child
# []
# droping this variant, probably artefact
# low qual 32038949_T_G in 77095350, checking inheritance; variant info: 0|1, 0.15675675675675677, 185
# {'spouse': 77095347, 'child': 77095354}
# 32038949_T_G not found in gt_hc of 77095354 - the child of 77095350
# 32038949_T_G not found in gt_dv of 77095354 - the child of 77095350
# no 32038949_T_G found in child
# []
# droping this variant, probably artefact
# low qual 32038955_A_T in 77095350, checking inheritance; variant info: 0|1, 0.16111111111111112, 180
# {'spouse': 77095347, 'child': 77095354}
# 32038955_A_T not found in gt_hc of 77095354 - the child of 77095350
# 32038955_A_T not found in gt_dv of 77095354 - the child of 77095350
# no 32038955_A_T found in child
# []
# droping this variant, probably artefact
# for 77095350 comparing 32039081_C_A with HC - 1|1 and DV - 1/0
# dv right with 1/0, VAF - 0.4936708860759494, DP-163
# for 77095354 comparing 32039015_G_A with HC - 1|1 and DV - 0/1
# hc right with 1|1, VAF - 1.0, DP-46
# for 77095354 comparing 32039027_C_G with HC - 1|1 and DV - 1/0
# hc right with 1|1, VAF - 0.9807692307692307, DP-52
# for 77095354 comparing 32039081_C_A with HC - 1|1 and DV - 1/0
# hc right with 1|1, VAF - 1.0, DP-243
# low qual 32038855_T_TTTG in 77095354, checking inheritance; variant info: 0/1, 0.17982456140350878, 228
# {'mother': 77095347, 'sibling': 77095349, 'father': 77095350}
# 32038855_T_TTTG not found in gt_hc of 77095347 - the mother of 77095354
# 32038855_T_TTTG not found in gt_dv of 77095347 - the mother of 77095354
# no 32038855_T_TTTG found in mother
# found 32038855_T_TTTG in 77095350 HC data - ['0|1', 0.23478260869565218, 115]
# checking relative variant with ['0|1', 0.23478260869565218, 115] AND ['0/1', 0.17903930131004367, 229]
# found 32038855_T_TTTG in father with genotype 0|1
# ['0|1']
# saving this variant even with bad QUAL
# low qual 32038855_T_TTG in 77095360, checking inheritance; variant info: 1|0, 0.14919735599622286, 2118
# {'sibling': 77095358, 'father': 77095361, 'mother': 77095363}
# 32038855_T_TTG not found in gt_hc of 77095361 - the father of 77095360
# 32038855_T_TTG not found in gt_dv of 77095361 - the father of 77095360
# no 32038855_T_TTG found in father
# 32038855_T_TTG not found in gt_hc of 77095363 - the mother of 77095360
# 32038855_T_TTG not found in gt_dv of 77095363 - the mother of 77095360
# no 32038855_T_TTG found in mother
# []
# droping this variant, probably artefact
# for 77095360 comparing 32038855_T_TTTG with HC - 1|0 and DV - 1/1
# dv right with 1/1, VAF - 0.8582089552238806, DP-134
# low qual 32038855_T_TTG in 77095362, checking inheritance; variant info: 1|0, 0.1612769485903814, 2419
# {'sibling': 77095358, 'father': 77095361, 'mother': 77095363}
# 32038855_T_TTG not found in gt_hc of 77095361 - the father of 77095362
# 32038855_T_TTG not found in gt_dv of 77095361 - the father of 77095362
# no 32038855_T_TTG found in father
# 32038855_T_TTG not found in gt_hc of 77095363 - the mother of 77095362
# 32038855_T_TTG not found in gt_dv of 77095363 - the mother of 77095362
# no 32038855_T_TTG found in mother
# []
# droping this variant, probably artefact
# for 77095362 comparing 32038855_T_TTTG with HC - 1|0 and DV - 1/1
# hc right with 1|0, VAF - 0.8387230514096186, DP-2419
# for 77095362 comparing 32041186_C_T with HC - 1|1 and DV - 0/1
# hc right with 1|1, VAF - 0.9983733224888166, DP-2459
# low qual 32038855_T_TTG in 77095384, checking inheritance; variant info: 1|0, 0.15266168059832821, 2286
# {'father': 77095383, 'mother': 77095381, 'sibling': 77095382}
# 32038855_T_TTG not found in gt_hc of 77095383 - the father of 77095384
# 32038855_T_TTG not found in gt_dv of 77095383 - the father of 77095384
# no 32038855_T_TTG found in father
# 32038855_T_TTG not found in gt_hc of 77095381 - the mother of 77095384
# 32038855_T_TTG not found in gt_dv of 77095381 - the mother of 77095384
# no 32038855_T_TTG found in mother
# []
# droping this variant, probably artefact
# for 77095384 comparing 32038855_T_TTTG with HC - 1|0 and DV - 1/1
# hc right with 1|0, VAF - 0.8473383194016718, DP-2286

# %%
left_aligned=defaultdict(dict)
for idx, row in files_list.iterrows():
    # dv
    vcf = read_vcf(row['dv'], mode = 'dv')
    vcf = vcf[vcf['FILTER'] == 'PASS']
    vcf = vcf[(vcf['POS'] >= calling_region[0]) & (vcf['POS'] <= calling_region[1])]
    if 32038855 in list(vcf['POS']):
        left_aligned[str(idx)+'_DV']={'POS': 32038855, 
                           'REF': vcf.loc[vcf['POS']==32038855, 'REF'].values[0],
                           'ALT': vcf.loc[vcf['POS']==32038855, 'ALT'].values[0],
                           'GT': vcf.loc[vcf['POS']==32038855, 'GT'].values[0],
                           'AD': vcf.loc[vcf['POS']==32038855, 'AD'].values[0]}
    # hc 
    vcf = read_vcf(row['hc'], mode='hc')
    vcf = vcf[(vcf['POS'] >= calling_region[0]) & (vcf['POS'] <= calling_region[1])]
    if 32038855 in list(vcf['POS']):
        left_aligned[str(idx)+'_HC']={'POS': 32038855, 
                           'REF': vcf.loc[vcf['POS']==32038855, 'REF'].values[0],
                           'ALT': vcf.loc[vcf['POS']==32038855, 'ALT'].values[0],
                           'GT': vcf.loc[vcf['POS']==32038855, 'GT'].values[0],
                           'AD': vcf.loc[vcf['POS']==32038855, 'AD'].values[0]}
    # gt_hc[idx]=gt_vectors(vcf, mode= 'hc')

# %%
conf=pd.DataFrame.from_dict(conflicts).transpose()
conf.to_excel('/storage/haplotypes/excels/conflicts.xlsx')

# %%
df=pd.DataFrame.from_dict(res)
df.columns = df.columns.astype(str)
df['pos'] = df.index.to_series().str.extract(r'^(\d+)').astype(int)
df['rest'] = df.index.to_series().str.extract(r'^\d+_(.+)$')
df_sorted = df.sort_values(by=['pos', 'rest']).drop(columns=['pos', 'rest'])
df_sorted.to_excel('/storage/haplotypes/excels/not_phased_sorted.xlsx')

# %%
df_af=df.copy()
df_af.head()
# Out:
#                 77050386 77091048 77092306 77092307 77092308 77092309  \
# 32038302_C_T         0|1      NaN      NaN      NaN      NaN      NaN
# 32038437_CCTG_C      1|0      NaN      NaN      NaN      NaN      NaN
# 32038540_C_T         1|1      1|1      1|0      0|1      1|1      NaN
# 32038560_C_A         1|1      0|1      1|0      0|1      1|1      NaN
# 32038820_C_T         0|1      1|1      NaN      0|1      0|1      NaN
#
#                 77092310 77092311 77092312 77092313  ... 77095381 77095382  \
# 32038302_C_T         NaN      NaN      NaN      NaN  ...      NaN      NaN
# 32038437_CCTG_C      NaN      0|1      NaN      1|0  ...      0|1      NaN
# 32038540_C_T         0|1      0|1      NaN      1|0  ...      0|1      0|1
# 32038560_C_A         0|1      0|1      NaN      1|0  ...      0|1      0|1
# 32038820_C_T         1|0      0|1      NaN      1|0  ...      1|0      NaN
#
#                 77095383 77095384 77095385 77095386 77095387 77095388  \
# 32038302_C_T         NaN      NaN      NaN      NaN      NaN      NaN
# 32038437_CCTG_C      NaN      NaN      NaN      1|1      1|1      1|0
# 32038540_C_T         1|0      NaN      1|1      1|1      1|1      1|0
# 32038560_C_A         1|0      NaN      1|1      1|1      1|1      1|0
# 32038820_C_T         NaN      NaN      NaN      1|1      1|1      0|1
#
#                 77095389 77095390
# 32038302_C_T         NaN      NaN
# 32038437_CCTG_C      NaN      NaN
# 32038540_C_T         0|1      1|0
# 32038560_C_A         NaN      1|0
# 32038820_C_T         1|1      1|0
#
# [5 rows x 571 columns]

# %%
to_phase= df.loc[:, df.apply(lambda col: col.isin(['1/0', '0/1']).any())]
to_phase.to_excel('/storage/haplotypes/excels/to_phase.xlsx')

# %%
def process_cell(value):
    if pd.isna(value):
        return 0
    # Replace both '/' and '|' with '+' and evaluate
    try:
        return eval(str(value).replace('/', '+').replace('|', '+'))
    except:
        return 0

# %%
processed_df = df.applymap(process_cell)
processed_df['haplotype_count'] = processed_df.sum(axis=1)
processed_df['AF_cohort'] = processed_df['haplotype_count']/1142
processed_df.to_excel('/storage/haplotypes/excels/w_af.xlsx')
# Out:
# /tmp/ipykernel_2772568/3509597075.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   processed_df = df.applymap(process_cell)

# %%
trios[77092370]
# Out:
# {'father': 77092368, 'mother': 77092371}

# %%
print(gt_hc[77092370]['32038949_T_G'], 'NONE', gt_dv[77092370]['32038949_T_G'], gt_dv[77092370]['32038949_T_C'], gt_bam[77092370]['32038949_T_G'], gt_bam[77092370]['32038949_T_C'])
# Out:
# ['1|1', 1.0, 25] NONE ['1/0', 0.7857142857142857, 168] ['1/0', 0.19642857142857142, 168] ['1/0', 0.35555555555555557, 90] ['1/0', 0.5666666666666667, 90]

# %%
print(gt_hc[77092368]['32038949_T_G'], 'NONE', 'NONE', 'NONE', 'NONE', 'NONE')
# Out:
# ['1|0', 0.5511111111111111, 225] NONE NONE NONE NONE NONE

# %%
print(gt_hc[77092371]['32038949_T_G'], 'NONE', 'NONE', 'NONE', gt_bam[77092371]['32038949_T_G'], 'NONE')
# Out:
# ['1|0', 0.5049035115469788, 3161] NONE NONE NONE ['0/1', 0.26745240253853125, 1103] NONE

# %%
trios[77095354]
# Out:
# {'mother': 77095347, 'sibling': 77095349, 'father': 77095350}

# %%
print('HC 32039015_G_T NONE', gt_hc[77095354]['32039015_G_A'], 'DV 32039015_G_T NONE', gt_dv[77095354]['32039015_G_A'], gt_bam[77095354]['32039015_G_T'], gt_bam[77095354]['32039015_G_A'])
# Out:
# HC 32039015_G_T NONE ['1|1', 1.0, 46] DV 32039015_G_T NONE ['0/1', 0.7916666666666666, 72] ['1/0', 0.3144208037825059, 846] ['1/0', 0.5638297872340425, 846]

# %%
print(gt_hc[77095354]['32039015_G_T'], gt_hc[77095354]['32039015_G_A'], gt_hc[77095354]['32039015_G_T'], gt_dv[77095354]['32039015_G_A'], gt_bam[77095354]['32039015_G_T'], gt_bam[77095354]['32039015_G_A'])

# %%
def manual_checking(patient, pos1, pos2, relatives):
    print(gt_hc[patient].get(pos1, f'{pos1} not found in HC data of {patient}'))
    print(gt_dv[patient].get(pos1, f'{pos1} not found in DV data of {patient}'))
    print(gt_bam[patient].get(pos1, f'{pos1} not found in bam data of {patient}'))
    print(gt_hc[patient].get(pos2, f'{pos2} not found in HC data of {patient}'))
    print(gt_dv[patient].get(pos2, f'{pos1} not found in DV data of {patient}'))
    print(gt_bam[patient].get(pos2, f'{pos1} not found in bam data of {patient}'))
    for rel in relatives[patient]:
        rel_num=int(relatives[patient][rel])
        print(f'searching in {rel_num}  - the {rel} of {patient}')
        print(gt_hc[rel_num].get(pos1, f'{pos1} not found in HC data of {rel_num}'))
        print(gt_dv[rel_num].get(pos1, f'{pos1} not found in DV data of {rel_num}'))
        print(gt_bam[rel_num].get(pos1, f'{pos1} not found in bam data of {rel_num}'))
        print(gt_hc[rel_num].get(pos2, f'{pos2} not found in HC data of {rel_num}'))
        print(gt_dv[rel_num].get(pos2, f'{pos1} not found in DV data of {rel_num}'))
        print(gt_bam[rel_num].get(pos2, f'{pos1} not found in bam data of {rel_num}'))


    return None

# %%
manual_checking(77092531, '32039002_G_A', '32039015_G_A', trios)
# Out:
# 32039002_G_A not found in HC data of 77092531
# ['1/1', 0.9487179487179487, 39]
# 32039002_G_A not found in bam data of 77092531
# 32039015_G_A not found in HC data of 77092531
# 32039002_G_A not found in DV data of 77092531
# 32039002_G_A not found in bam data of 77092531
# searching in 77092530  - the father of 77092531
# ['0|1', 0.23255813953488372, 43]
# 32039002_G_A not found in DV data of 77092530
# 32039002_G_A not found in bam data of 77092530
# 32039015_G_A not found in HC data of 77092530
# 32039002_G_A not found in DV data of 77092530
# 32039002_G_A not found in bam data of 77092530
# searching in 77092529  - the mother of 77092531
# ['0|1', 0.125, 24]
# 32039002_G_A not found in DV data of 77092529
# 32039002_G_A not found in bam data of 77092529
# 32039015_G_A not found in HC data of 77092529
# 32039002_G_A not found in DV data of 77092529
# 32039002_G_A not found in bam data of 77092529
